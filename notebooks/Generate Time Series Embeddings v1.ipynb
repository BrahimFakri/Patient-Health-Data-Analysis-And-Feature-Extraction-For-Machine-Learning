# %%
import os
os.chdir('../')

from src.data import constants
from src.utils import Extract_features_all_events

import pandas as pd

# %% [markdown]
# # Create chart events features for patient cohort

# %%
chart_fusion = []
for patient in constants.cohort:

    chart_fusion.append(Extract_features_all_events.extract_chart_events(constants.chartevents, patient))
    
chart_fusion
# Out:
# 10004235
# C:\Users\B\Desktop\fresh start\src\utils\Extract_features_all_events.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.93s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.33s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.68s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.02s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.89s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.79s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.84s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.81s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.88s/it]
# 10004720
# C:\Users\B\Desktop\fresh start\src\utils\Extract_features_all_events.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.49s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.09s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.10s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.98s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.98s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.22s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.09s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.02s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.93s/it]
# 10019003
# C:\Users\B\Desktop\fresh start\src\utils\Extract_features_all_events.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.43s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.07s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.98s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.85s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.88s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.00s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.92s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.21s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.01s/it]
# 10020852
# C:\Users\B\Desktop\fresh start\src\utils\Extract_features_all_events.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.33s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.82s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.85s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.80s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.82s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.81s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.82s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.83s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.80s/it]
# 10023708
# C:\Users\B\Desktop\fresh start\src\utils\Extract_features_all_events.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.55s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.94s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.86s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.84s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.85s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.96s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.02s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.87s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.92s/it]
# 10031358
# C:\Users\B\Desktop\fresh start\src\utils\Extract_features_all_events.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.83s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.65s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.50s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.99s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.26s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.27s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.89s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.98s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.09s/it]
# 10035631
# C:\Users\B\Desktop\fresh start\src\utils\Extract_features_all_events.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.99s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.27s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.11s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.06s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.14s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.12s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.05s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.14s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.18s/it]
# 10046166
# C:\Users\B\Desktop\fresh start\src\utils\Extract_features_all_events.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.16s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.10s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.10s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.19s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.16s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.17s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.10s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.94s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  3.00s/it]
# 10047172
# C:\Users\B\Desktop\fresh start\src\utils\Extract_features_all_events.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.16s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.19s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.07s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.94s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.00s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.05s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.97s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.14s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.94s/it]
# 10051990
# C:\Users\B\Desktop\fresh start\src\utils\Extract_features_all_events.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.14s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.14s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.05s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.07s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.99s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.02s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.03s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.97s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.09s/it]
# [          Heart Rate__length  Heart Rate__absolute_sum_of_changes  \
#  10004235               121.0                                694.0
#
#            Heart Rate__maximum  Heart Rate__mean  Heart Rate__mean_abs_change  \
#  10004235                144.0        113.115702                     5.783333
#
#            Heart Rate__mean_change  Heart Rate__median  Heart Rate__minimum  \
#  10004235                -0.183333               112.0                 87.0
#
#            Heart Rate__standard_deviation  Heart Rate__variance  ...  \
#  10004235                       10.262014            105.308927  ...
#
#            GCS - Motor Response__large_standard_deviation__r_0.8  \
#  10004235                                                0.0
#
#            GCS - Motor Response__quantile__q_0.25  \
#  10004235                                    4.75
#
#            GCS - Motor Response__quantile__q_0.5  \
#  10004235                                    6.0
#
#            GCS - Motor Response__quantile__q_0.75  \
#  10004235                                     6.0
#
#            GCS - Motor Response__quantile__q_1  \
#  10004235                                  6.0
#
#            GCS - Motor Response__linear_trend__attr_"pvalue"  \
#  10004235                                            0.00102
#
#            GCS - Motor Response__linear_trend__attr_"rvalue"  \
#  10004235                                           0.627887
#
#            GCS - Motor Response__linear_trend__attr_"intercept"  \
#  10004235                                               3.61
#
#            GCS - Motor Response__linear_trend__attr_"slope"  \
#  10004235                                          0.131739
#
#            GCS - Motor Response__linear_trend__attr_"stderr"
#  10004235                                           0.034815
#
#  [1 rows x 207 columns],
#            Heart Rate__length  Heart Rate__absolute_sum_of_changes  \
#  10004720               142.0                                836.0
#
#            Heart Rate__maximum  Heart Rate__mean  Heart Rate__mean_abs_change  \
#  10004720                122.0         83.119718                     5.929078
#
#            Heart Rate__mean_change  Heart Rate__median  Heart Rate__minimum  \
#  10004720                -0.553191                78.0                  0.0
#
#            Heart Rate__standard_deviation  Heart Rate__variance  ...  \
#  10004720                       18.472851            341.246231  ...
#
#            GCS - Motor Response__large_standard_deviation__r_0.8  \
#  10004720                                                0.0
#
#            GCS - Motor Response__quantile__q_0.25  \
#  10004720                                     1.0
#
#            GCS - Motor Response__quantile__q_0.5  \
#  10004720                                    1.0
#
#            GCS - Motor Response__quantile__q_0.75  \
#  10004720                                     1.0
#
#            GCS - Motor Response__quantile__q_1  \
#  10004720                                  2.0
#
#            GCS - Motor Response__linear_trend__attr_"pvalue"  \
#  10004720                                           0.135912
#
#            GCS - Motor Response__linear_trend__attr_"rvalue"  \
#  10004720                                           0.306698
#
#            GCS - Motor Response__linear_trend__attr_"intercept"  \
#  10004720                                           0.941538
#
#            GCS - Motor Response__linear_trend__attr_"slope"  \
#  10004720                                          0.011538
#
#            GCS - Motor Response__linear_trend__attr_"stderr"
#  10004720                                           0.007467
#
#  [1 rows x 207 columns],
#            Heart Rate__length  Heart Rate__absolute_sum_of_changes  \
#  10019003               267.0                                759.0
#
#            Heart Rate__maximum  Heart Rate__mean  Heart Rate__mean_abs_change  \
#  10019003                128.0         88.277154                     2.853383
#
#            Heart Rate__mean_change  Heart Rate__median  Heart Rate__minimum  \
#  10019003                -0.086466                83.0                 69.0
#
#            Heart Rate__standard_deviation  Heart Rate__variance  ...  \
#  10019003                       13.545525            183.481238  ...
#
#            GCS - Motor Response__large_standard_deviation__r_0.8  \
#  10019003                                                0.0
#
#            GCS - Motor Response__quantile__q_0.25  \
#  10019003                                     6.0
#
#            GCS - Motor Response__quantile__q_0.5  \
#  10019003                                    6.0
#
#            GCS - Motor Response__quantile__q_0.75  \
#  10019003                                     6.0
#
#            GCS - Motor Response__quantile__q_1  \
#  10019003                                  6.0
#
#            GCS - Motor Response__linear_trend__attr_"pvalue"  \
#  10019003                                           0.537253
#
#            GCS - Motor Response__linear_trend__attr_"rvalue"  \
#  10019003                                           0.090289
#
#            GCS - Motor Response__linear_trend__attr_"intercept"  \
#  10019003                                           5.804082
#
#            GCS - Motor Response__linear_trend__attr_"slope"  \
#  10019003                                          0.003061
#
#            GCS - Motor Response__linear_trend__attr_"stderr"
#  10019003                                           0.004925
#
#  [1 rows x 207 columns],
#            Heart Rate__length  Heart Rate__absolute_sum_of_changes  \
#  10020852                43.0                                235.0
#
#            Heart Rate__maximum  Heart Rate__mean  Heart Rate__mean_abs_change  \
#  10020852                 93.0         72.418605                     5.595238
#
#            Heart Rate__mean_change  Heart Rate__median  Heart Rate__minimum  \
#  10020852                     -0.5                71.0                 56.0
#
#            Heart Rate__standard_deviation  Heart Rate__variance  ...  \
#  10020852                        8.521471             72.615468  ...
#
#            GCS - Motor Response__large_standard_deviation__r_0.8  \
#  10020852                                                0.0
#
#            GCS - Motor Response__quantile__q_0.25  \
#  10020852                                     6.0
#
#            GCS - Motor Response__quantile__q_0.5  \
#  10020852                                    6.0
#
#            GCS - Motor Response__quantile__q_0.75  \
#  10020852                                     6.0
#
#            GCS - Motor Response__quantile__q_1  \
#  10020852                                  6.0
#
#            GCS - Motor Response__linear_trend__attr_"pvalue"  \
#  10020852                                                1.0
#
#            GCS - Motor Response__linear_trend__attr_"rvalue"  \
#  10020852                                                0.0
#
#            GCS - Motor Response__linear_trend__attr_"intercept"  \
#  10020852                                                6.0
#
#            GCS - Motor Response__linear_trend__attr_"slope"  \
#  10020852                                               0.0
#
#            GCS - Motor Response__linear_trend__attr_"stderr"
#  10020852                                                0.0
#
#  [1 rows x 207 columns],
#            Heart Rate__length  Heart Rate__absolute_sum_of_changes  \
#  10023708                59.0                                268.0
#
#            Heart Rate__maximum  Heart Rate__mean  Heart Rate__mean_abs_change  \
#  10023708                 88.0         71.745763                      4.62069
#
#            Heart Rate__mean_change  Heart Rate__median  Heart Rate__minimum  \
#  10023708                -0.275862                73.0                 58.0
#
#            Heart Rate__standard_deviation  Heart Rate__variance  ...  \
#  10023708                        7.240641             52.426889  ...
#
#            GCS - Motor Response__large_standard_deviation__r_0.8  \
#  10023708                                                0.0
#
#            GCS - Motor Response__quantile__q_0.25  \
#  10023708                                     6.0
#
#            GCS - Motor Response__quantile__q_0.5  \
#  10023708                                    6.0
#
#            GCS - Motor Response__quantile__q_0.75  \
#  10023708                                     6.0
#
#            GCS - Motor Response__quantile__q_1  \
#  10023708                                  6.0
#
#            GCS - Motor Response__linear_trend__attr_"pvalue"  \
#  10023708                                                1.0
#
#            GCS - Motor Response__linear_trend__attr_"rvalue"  \
#  10023708                                                0.0
#
#            GCS - Motor Response__linear_trend__attr_"intercept"  \
#  10023708                                                6.0
#
#            GCS - Motor Response__linear_trend__attr_"slope"  \
#  10023708                                               0.0
#
#            GCS - Motor Response__linear_trend__attr_"stderr"
#  10023708                                                0.0
#
#  [1 rows x 207 columns],
#            Heart Rate__length  Heart Rate__absolute_sum_of_changes  \
#  10031358                20.0                                103.0
#
#            Heart Rate__maximum  Heart Rate__mean  Heart Rate__mean_abs_change  \
#  10031358                 91.0             73.45                     5.421053
#
#            Heart Rate__mean_change  Heart Rate__median  Heart Rate__minimum  \
#  10031358                -0.157895                73.0                 58.0
#
#            Heart Rate__standard_deviation  Heart Rate__variance  ...  \
#  10031358                       10.947488              119.8475  ...
#
#            GCS - Motor Response__large_standard_deviation__r_0.8  \
#  10031358                                                0.0
#
#            GCS - Motor Response__quantile__q_0.25  \
#  10031358                                     6.0
#
#            GCS - Motor Response__quantile__q_0.5  \
#  10031358                                    6.0
#
#            GCS - Motor Response__quantile__q_0.75  \
#  10031358                                     6.0
#
#            GCS - Motor Response__quantile__q_1  \
#  10031358                                  6.0
#
#            GCS - Motor Response__linear_trend__attr_"pvalue"  \
#  10031358                                                1.0
#
#            GCS - Motor Response__linear_trend__attr_"rvalue"  \
#  10031358                                                0.0
#
#            GCS - Motor Response__linear_trend__attr_"intercept"  \
#  10031358                                                6.0
#
#            GCS - Motor Response__linear_trend__attr_"slope"  \
#  10031358                                               0.0
#
#            GCS - Motor Response__linear_trend__attr_"stderr"
#  10031358                                                0.0
#
#  [1 rows x 207 columns],
#            Heart Rate__length  Heart Rate__absolute_sum_of_changes  \
#  10035631               364.0                               1268.0
#
#            Heart Rate__maximum  Heart Rate__mean  Heart Rate__mean_abs_change  \
#  10035631                174.0        107.332418                     3.493113
#
#            Heart Rate__mean_change  Heart Rate__median  Heart Rate__minimum  \
#  10035631                -0.044077               103.0                 81.0
#
#            Heart Rate__standard_deviation  Heart Rate__variance  ...  \
#  10035631                       14.921109            222.639499  ...
#
#            GCS - Motor Response__large_standard_deviation__r_0.8  \
#  10035631                                                0.0
#
#            GCS - Motor Response__quantile__q_0.25  \
#  10035631                                     5.0
#
#            GCS - Motor Response__quantile__q_0.5  \
#  10035631                                    5.0
#
#            GCS - Motor Response__quantile__q_0.75  \
#  10035631                                     6.0
#
#            GCS - Motor Response__quantile__q_1  \
#  10035631                                  6.0
#
#            GCS - Motor Response__linear_trend__attr_"pvalue"  \
#  10035631                                           0.793001
#
#            GCS - Motor Response__linear_trend__attr_"rvalue"  \
#  10035631                                           0.034299
#
#            GCS - Motor Response__linear_trend__attr_"intercept"  \
#  10035631                                           4.602856
#
#            GCS - Motor Response__linear_trend__attr_"slope"  \
#  10035631                                          0.002856
#
#            GCS - Motor Response__linear_trend__attr_"stderr"
#  10035631                                           0.010833
#
#  [1 rows x 207 columns],
#            Heart Rate__length  Heart Rate__absolute_sum_of_changes  \
#  10046166                23.0                                100.0
#
#            Heart Rate__maximum  Heart Rate__mean  Heart Rate__mean_abs_change  \
#  10046166                 71.0         56.173913                     4.545455
#
#            Heart Rate__mean_change  Heart Rate__median  Heart Rate__minimum  \
#  10046166                 0.363636                55.0                 46.0
#
#            Heart Rate__standard_deviation  Heart Rate__variance  ...  \
#  10046166                        6.862958             47.100189  ...
#
#            GCS - Motor Response__large_standard_deviation__r_0.8  \
#  10046166                                                0.0
#
#            GCS - Motor Response__quantile__q_0.25  \
#  10046166                                     6.0
#
#            GCS - Motor Response__quantile__q_0.5  \
#  10046166                                    6.0
#
#            GCS - Motor Response__quantile__q_0.75  \
#  10046166                                     6.0
#
#            GCS - Motor Response__quantile__q_1  \
#  10046166                                  6.0
#
#            GCS - Motor Response__linear_trend__attr_"pvalue"  \
#  10046166                                                1.0
#
#            GCS - Motor Response__linear_trend__attr_"rvalue"  \
#  10046166                                                0.0
#
#            GCS - Motor Response__linear_trend__attr_"intercept"  \
#  10046166                                                6.0
#
#            GCS - Motor Response__linear_trend__attr_"slope"  \
#  10046166                                               0.0
#
#            GCS - Motor Response__linear_trend__attr_"stderr"
#  10046166                                                0.0
#
#  [1 rows x 207 columns],
#            Heart Rate__length  Heart Rate__absolute_sum_of_changes  \
#  10047172                45.0                                193.0
#
#            Heart Rate__maximum  Heart Rate__mean  Heart Rate__mean_abs_change  \
#  10047172                 93.0         79.288889                     4.386364
#
#            Heart Rate__mean_change  Heart Rate__median  Heart Rate__minimum  \
#  10047172                -0.113636                80.0                 65.0
#
#            Heart Rate__standard_deviation  Heart Rate__variance  ...  \
#  10047172                        9.130224             83.360988  ...
#
#            GCS - Motor Response__large_standard_deviation__r_0.8  \
#  10047172                                                0.0
#
#            GCS - Motor Response__quantile__q_0.25  \
#  10047172                                     6.0
#
#            GCS - Motor Response__quantile__q_0.5  \
#  10047172                                    6.0
#
#            GCS - Motor Response__quantile__q_0.75  \
#  10047172                                     6.0
#
#            GCS - Motor Response__quantile__q_1  \
#  10047172                                  6.0
#
#            GCS - Motor Response__linear_trend__attr_"pvalue"  \
#  10047172                                                1.0
#
#            GCS - Motor Response__linear_trend__attr_"rvalue"  \
#  10047172                                                0.0
#
#            GCS - Motor Response__linear_trend__attr_"intercept"  \
#  10047172                                                6.0
#
#            GCS - Motor Response__linear_trend__attr_"slope"  \
#  10047172                                               0.0
#
#            GCS - Motor Response__linear_trend__attr_"stderr"
#  10047172                                                0.0
#
#  [1 rows x 207 columns],
#            Heart Rate__length  Heart Rate__absolute_sum_of_changes  \
#  10051990                52.0                                132.0
#
#            Heart Rate__maximum  Heart Rate__mean  Heart Rate__mean_abs_change  \
#  10051990                100.0         91.980769                     2.588235
#
#            Heart Rate__mean_change  Heart Rate__median  Heart Rate__minimum  \
#  10051990                -0.156863                92.0                 85.0
#
#            Heart Rate__standard_deviation  Heart Rate__variance  ...  \
#  10051990                        3.422158             11.711169  ...
#
#            GCS - Motor Response__large_standard_deviation__r_0.8  \
#  10051990                                                0.0
#
#            GCS - Motor Response__quantile__q_0.25  \
#  10051990                                     6.0
#
#            GCS - Motor Response__quantile__q_0.5  \
#  10051990                                    6.0
#
#            GCS - Motor Response__quantile__q_0.75  \
#  10051990                                     6.0
#
#            GCS - Motor Response__quantile__q_1  \
#  10051990                                  6.0
#
#            GCS - Motor Response__linear_trend__attr_"pvalue"  \
#  10051990                                                1.0
#
#            GCS - Motor Response__linear_trend__attr_"rvalue"  \
#  10051990                                                0.0
#
#            GCS - Motor Response__linear_trend__attr_"intercept"  \
#  10051990                                                6.0
#
#            GCS - Motor Response__linear_trend__attr_"slope"  \
#  10051990                                               0.0
#
#            GCS - Motor Response__linear_trend__attr_"stderr"
#  10051990                                                0.0
#
#  [1 rows x 207 columns]]

# %% [markdown]
# ### Concatenate chart events fusion features

# %%
chart_fusion = pd.concat(chart_fusion, axis=0)

# %%
chart_fusion
# Out:
#           Heart Rate__length  Heart Rate__absolute_sum_of_changes  \
# 10004235               121.0                                694.0
# 10004720               142.0                                836.0
# 10019003               267.0                                759.0
# 10020852                43.0                                235.0
# 10023708                59.0                                268.0
# 10031358                20.0                                103.0
# 10035631               364.0                               1268.0
# 10046166                23.0                                100.0
# 10047172                45.0                                193.0
# 10051990                52.0                                132.0
#
#           Heart Rate__maximum  Heart Rate__mean  Heart Rate__mean_abs_change  \
# 10004235                144.0        113.115702                     5.783333
# 10004720                122.0         83.119718                     5.929078
# 10019003                128.0         88.277154                     2.853383
# 10020852                 93.0         72.418605                     5.595238
# 10023708                 88.0         71.745763                     4.620690
# 10031358                 91.0         73.450000                     5.421053
# 10035631                174.0        107.332418                     3.493113
# 10046166                 71.0         56.173913                     4.545455
# 10047172                 93.0         79.288889                     4.386364
# 10051990                100.0         91.980769                     2.588235
#
#           Heart Rate__mean_change  Heart Rate__median  Heart Rate__minimum  \
# 10004235                -0.183333               112.0                 87.0
# 10004720                -0.553191                78.0                  0.0
# 10019003                -0.086466                83.0                 69.0
# 10020852                -0.500000                71.0                 56.0
# 10023708                -0.275862                73.0                 58.0
# 10031358                -0.157895                73.0                 58.0
# 10035631                -0.044077               103.0                 81.0
# 10046166                 0.363636                55.0                 46.0
# 10047172                -0.113636                80.0                 65.0
# 10051990                -0.156863                92.0                 85.0
#
#           Heart Rate__standard_deviation  Heart Rate__variance  ...  \
# 10004235                       10.262014            105.308927  ...
# 10004720                       18.472851            341.246231  ...
# 10019003                       13.545525            183.481238  ...
# 10020852                        8.521471             72.615468  ...
# 10023708                        7.240641             52.426889  ...
# 10031358                       10.947488            119.847500  ...
# 10035631                       14.921109            222.639499  ...
# 10046166                        6.862958             47.100189  ...
# 10047172                        9.130224             83.360988  ...
# 10051990                        3.422158             11.711169  ...
#
#           GCS - Motor Response__large_standard_deviation__r_0.8  \
# 10004235                                                0.0
# 10004720                                                0.0
# 10019003                                                0.0
# 10020852                                                0.0
# 10023708                                                0.0
# 10031358                                                0.0
# 10035631                                                0.0
# 10046166                                                0.0
# 10047172                                                0.0
# 10051990                                                0.0
#
#           GCS - Motor Response__quantile__q_0.25  \
# 10004235                                    4.75
# 10004720                                    1.00
# 10019003                                    6.00
# 10020852                                    6.00
# 10023708                                    6.00
# 10031358                                    6.00
# 10035631                                    5.00
# 10046166                                    6.00
# 10047172                                    6.00
# 10051990                                    6.00
#
#           GCS - Motor Response__quantile__q_0.5  \
# 10004235                                    6.0
# 10004720                                    1.0
# 10019003                                    6.0
# 10020852                                    6.0
# 10023708                                    6.0
# 10031358                                    6.0
# 10035631                                    5.0
# 10046166                                    6.0
# 10047172                                    6.0
# 10051990                                    6.0
#
#           GCS - Motor Response__quantile__q_0.75  \
# 10004235                                     6.0
# 10004720                                     1.0
# 10019003                                     6.0
# 10020852                                     6.0
# 10023708                                     6.0
# 10031358                                     6.0
# 10035631                                     6.0
# 10046166                                     6.0
# 10047172                                     6.0
# 10051990                                     6.0
#
#           GCS - Motor Response__quantile__q_1  \
# 10004235                                  6.0
# 10004720                                  2.0
# 10019003                                  6.0
# 10020852                                  6.0
# 10023708                                  6.0
# 10031358                                  6.0
# 10035631                                  6.0
# 10046166                                  6.0
# 10047172                                  6.0
# 10051990                                  6.0
#
#           GCS - Motor Response__linear_trend__attr_"pvalue"  \
# 10004235                                           0.001020
# 10004720                                           0.135912
# 10019003                                           0.537253
# 10020852                                           1.000000
# 10023708                                           1.000000
# 10031358                                           1.000000
# 10035631                                           0.793001
# 10046166                                           1.000000
# 10047172                                           1.000000
# 10051990                                           1.000000
#
#           GCS - Motor Response__linear_trend__attr_"rvalue"  \
# 10004235                                           0.627887
# 10004720                                           0.306698
# 10019003                                           0.090289
# 10020852                                           0.000000
# 10023708                                           0.000000
# 10031358                                           0.000000
# 10035631                                           0.034299
# 10046166                                           0.000000
# 10047172                                           0.000000
# 10051990                                           0.000000
#
#           GCS - Motor Response__linear_trend__attr_"intercept"  \
# 10004235                                           3.610000
# 10004720                                           0.941538
# 10019003                                           5.804082
# 10020852                                           6.000000
# 10023708                                           6.000000
# 10031358                                           6.000000
# 10035631                                           4.602856
# 10046166                                           6.000000
# 10047172                                           6.000000
# 10051990                                           6.000000
#
#           GCS - Motor Response__linear_trend__attr_"slope"  \
# 10004235                                          0.131739
# 10004720                                          0.011538
# 10019003                                          0.003061
# 10020852                                          0.000000
# 10023708                                          0.000000
# 10031358                                          0.000000
# 10035631                                          0.002856
# 10046166                                          0.000000
# 10047172                                          0.000000
# 10051990                                          0.000000
#
#           GCS - Motor Response__linear_trend__attr_"stderr"
# 10004235                                           0.034815
# 10004720                                           0.007467
# 10019003                                           0.004925
# 10020852                                           0.000000
# 10023708                                           0.000000
# 10031358                                           0.000000
# 10035631                                           0.010833
# 10046166                                           0.000000
# 10047172                                           0.000000
# 10051990                                           0.000000
#
# [10 rows x 207 columns]

# %% [markdown]
# # Create lab events features for patient cohort

# %%
lab_fusion = []
for patient in constants.cohort:
    
    lab_fusion.append(Extract_features_all_events.extract_lab_events(constants.labevents, patient))
    
lab_fusion
# Out:
# 10004235
# C:\Users\B\Desktop\fresh start\src\utils\Extract_features_all_events.py:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.28s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.02s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.02s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.09s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.00s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.01s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.94s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.01s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.98s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.21s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.03s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.02s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.02s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.23s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.21s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  3.00s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.27s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.30s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.08s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.11s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.27s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.63s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.44s/it]
# [          Glucose__length  Glucose__absolute_sum_of_changes  Glucose__maximum  \
#  10004235              2.0                              40.0             174.0
#
#            Glucose__mean  Glucose__mean_abs_change  Glucose__mean_change  \
#  10004235          154.0                      40.0                 -40.0
#
#            Glucose__median  Glucose__minimum  Glucose__standard_deviation  \
#  10004235            154.0             134.0                         20.0
#
#            Glucose__variance  ...  Vancomycin__large_standard_deviation__r_0.8  \
#  10004235              400.0  ...                                          0.0
#
#            Vancomycin__quantile__q_0.25  Vancomycin__quantile__q_0.5  \
#  10004235                          10.2                         10.4
#
#            Vancomycin__quantile__q_0.75  Vancomycin__quantile__q_1  \
#  10004235                          11.2                       12.0
#
#            Vancomycin__linear_trend__attr_"pvalue"  \
#  10004235                                 0.212296
#
#            Vancomycin__linear_trend__attr_"rvalue"  \
#  10004235                                 0.944911
#
#            Vancomycin__linear_trend__attr_"intercept"  \
#  10004235                                         9.8
#
#            Vancomycin__linear_trend__attr_"slope"  \
#  10004235                                     1.0
#
#            Vancomycin__linear_trend__attr_"stderr"
#  10004235                                  0.34641
#
#  [1 rows x 529 columns]]

# %% [markdown]
# ### Concatenate lab events fusion features

# %%
lab_fusion = pd.concat(lab_fusion, axis=0)

# %%
lab_fusion
# Out:
#           Glucose__length  Glucose__absolute_sum_of_changes  Glucose__maximum  \
# 10004235              2.0                              40.0             174.0
#
#           Glucose__mean  Glucose__mean_abs_change  Glucose__mean_change  \
# 10004235          154.0                      40.0                 -40.0
#
#           Glucose__median  Glucose__minimum  Glucose__standard_deviation  \
# 10004235            154.0             134.0                         20.0
#
#           Glucose__variance  ...  Vancomycin__large_standard_deviation__r_0.8  \
# 10004235              400.0  ...                                          0.0
#
#           Vancomycin__quantile__q_0.25  Vancomycin__quantile__q_0.5  \
# 10004235                          10.2                         10.4
#
#           Vancomycin__quantile__q_0.75  Vancomycin__quantile__q_1  \
# 10004235                          11.2                       12.0
#
#           Vancomycin__linear_trend__attr_"pvalue"  \
# 10004235                                 0.212296
#
#           Vancomycin__linear_trend__attr_"rvalue"  \
# 10004235                                 0.944911
#
#           Vancomycin__linear_trend__attr_"intercept"  \
# 10004235                                         9.8
#
#           Vancomycin__linear_trend__attr_"slope"  \
# 10004235                                     1.0
#
#           Vancomycin__linear_trend__attr_"stderr"
# 10004235                                  0.34641
#
# [1 rows x 529 columns]

# %% [markdown]
# # Create procedure events features for patient cohort

# %%
procedure_fusion = []
for patient in constants.cohort[8:9]:
   
    procedure_fusion.append(Extract_features_all_events.extract_procedure_events(constants.procedureevents, patient))
    
procedure_fusion

# %%
procedure_fusion = pd.concat(procedure_fusion, axis=0)

# %% [markdown]
# # Concatenate fusion features horizontally for all patients

# %%
fusion_dataframe = pd.concat([chart_fusion, lab_fusion], axis=1)

# %%
fusion_dataframe.index.names = ["subject_id"]

# %%
fusion_dataframe
# Out:
#             Heart Rate__length  Heart Rate__absolute_sum_of_changes  \
# subject_id
# 10004235                 121.0                                694.0
# 10004720                 142.0                                836.0
# 10019003                 267.0                                759.0
# 10020852                  43.0                                235.0
# 10023708                  59.0                                268.0
# 10031358                  20.0                                103.0
# 10035631                 364.0                               1268.0
# 10046166                  23.0                                100.0
# 10047172                  45.0                                193.0
# 10051990                  52.0                                132.0
#
#             Heart Rate__maximum  Heart Rate__mean  \
# subject_id
# 10004235                  144.0        113.115702
# 10004720                  122.0         83.119718
# 10019003                  128.0         88.277154
# 10020852                   93.0         72.418605
# 10023708                   88.0         71.745763
# 10031358                   91.0         73.450000
# 10035631                  174.0        107.332418
# 10046166                   71.0         56.173913
# 10047172                   93.0         79.288889
# 10051990                  100.0         91.980769
#
#             Heart Rate__mean_abs_change  Heart Rate__mean_change  \
# subject_id
# 10004235                       5.783333                -0.183333
# 10004720                       5.929078                -0.553191
# 10019003                       2.853383                -0.086466
# 10020852                       5.595238                -0.500000
# 10023708                       4.620690                -0.275862
# 10031358                       5.421053                -0.157895
# 10035631                       3.493113                -0.044077
# 10046166                       4.545455                 0.363636
# 10047172                       4.386364                -0.113636
# 10051990                       2.588235                -0.156863
#
#             Heart Rate__median  Heart Rate__minimum  \
# subject_id
# 10004235                 112.0                 87.0
# 10004720                  78.0                  0.0
# 10019003                  83.0                 69.0
# 10020852                  71.0                 56.0
# 10023708                  73.0                 58.0
# 10031358                  73.0                 58.0
# 10035631                 103.0                 81.0
# 10046166                  55.0                 46.0
# 10047172                  80.0                 65.0
# 10051990                  92.0                 85.0
#
#             Heart Rate__standard_deviation  Heart Rate__variance  ...  \
# subject_id                                                        ...
# 10004235                         10.262014            105.308927  ...
# 10004720                         18.472851            341.246231  ...
# 10019003                         13.545525            183.481238  ...
# 10020852                          8.521471             72.615468  ...
# 10023708                          7.240641             52.426889  ...
# 10031358                         10.947488            119.847500  ...
# 10035631                         14.921109            222.639499  ...
# 10046166                          6.862958             47.100189  ...
# 10047172                          9.130224             83.360988  ...
# 10051990                          3.422158             11.711169  ...
#
#             Vancomycin__large_standard_deviation__r_0.8  \
# subject_id
# 10004235                                            0.0
# 10004720                                            NaN
# 10019003                                            NaN
# 10020852                                            NaN
# 10023708                                            NaN
# 10031358                                            NaN
# 10035631                                            NaN
# 10046166                                            NaN
# 10047172                                            NaN
# 10051990                                            NaN
#
#             Vancomycin__quantile__q_0.25  Vancomycin__quantile__q_0.5  \
# subject_id
# 10004235                            10.2                         10.4
# 10004720                             NaN                          NaN
# 10019003                             NaN                          NaN
# 10020852                             NaN                          NaN
# 10023708                             NaN                          NaN
# 10031358                             NaN                          NaN
# 10035631                             NaN                          NaN
# 10046166                             NaN                          NaN
# 10047172                             NaN                          NaN
# 10051990                             NaN                          NaN
#
#             Vancomycin__quantile__q_0.75  Vancomycin__quantile__q_1  \
# subject_id
# 10004235                            11.2                       12.0
# 10004720                             NaN                        NaN
# 10019003                             NaN                        NaN
# 10020852                             NaN                        NaN
# 10023708                             NaN                        NaN
# 10031358                             NaN                        NaN
# 10035631                             NaN                        NaN
# 10046166                             NaN                        NaN
# 10047172                             NaN                        NaN
# 10051990                             NaN                        NaN
#
#             Vancomycin__linear_trend__attr_"pvalue"  \
# subject_id
# 10004235                                   0.212296
# 10004720                                        NaN
# 10019003                                        NaN
# 10020852                                        NaN
# 10023708                                        NaN
# 10031358                                        NaN
# 10035631                                        NaN
# 10046166                                        NaN
# 10047172                                        NaN
# 10051990                                        NaN
#
#             Vancomycin__linear_trend__attr_"rvalue"  \
# subject_id
# 10004235                                   0.944911
# 10004720                                        NaN
# 10019003                                        NaN
# 10020852                                        NaN
# 10023708                                        NaN
# 10031358                                        NaN
# 10035631                                        NaN
# 10046166                                        NaN
# 10047172                                        NaN
# 10051990                                        NaN
#
#             Vancomycin__linear_trend__attr_"intercept"  \
# subject_id
# 10004235                                           9.8
# 10004720                                           NaN
# 10019003                                           NaN
# 10020852                                           NaN
# 10023708                                           NaN
# 10031358                                           NaN
# 10035631                                           NaN
# 10046166                                           NaN
# 10047172                                           NaN
# 10051990                                           NaN
#
#             Vancomycin__linear_trend__attr_"slope"  \
# subject_id
# 10004235                                       1.0
# 10004720                                       NaN
# 10019003                                       NaN
# 10020852                                       NaN
# 10023708                                       NaN
# 10031358                                       NaN
# 10035631                                       NaN
# 10046166                                       NaN
# 10047172                                       NaN
# 10051990                                       NaN
#
#             Vancomycin__linear_trend__attr_"stderr"
# subject_id
# 10004235                                    0.34641
# 10004720                                        NaN
# 10019003                                        NaN
# 10020852                                        NaN
# 10023708                                        NaN
# 10031358                                        NaN
# 10035631                                        NaN
# 10046166                                        NaN
# 10047172                                        NaN
# 10051990                                        NaN
#
# [10 rows x 736 columns]

# %%
fusion_dataframe.to_csv("csvs/fusion_dataframe.csv", index=True)

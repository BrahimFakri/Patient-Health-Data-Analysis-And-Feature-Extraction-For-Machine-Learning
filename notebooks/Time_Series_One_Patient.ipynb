# %% [markdown]
# This notebook is the illustration of how to extract Time Series features from the chartevents data for one single patient that has both icu and cxr data.
#
# To obtain the list of all patients who have icu and cxr data, please run the following notebook: ```icu_cxr_patients.ipynb```

# %% [markdown]
# Imports

# %%
import os
os.chdir('../')

from src.data import constants
import pandas as pd
from pandas import read_csv
import datetime as dt
import numpy as np

import tsfresh
from tsfresh import extract_features

# %% [markdown]
# #### Chart events example

# %% [markdown]
# Read all data from chartevents and d_items

# %% [markdown]
# chartevents dataframe

# %%
df_chartevents =read_csv(constants.chartevents,low_memory=False, dtype={'value': 'object', 'valueuom': 'object'}, nrows=20000000)

# %% [markdown]
# d_items dataframe

# %%
df_d_items = pd.read_csv(constants.d_items)

# %%
df_d_items.head()
# Out:
#    itemid                    label        abbreviation         linksto  \
# 0  220003       ICU Admission date  ICU Admission date  datetimeevents
# 1  220045               Heart Rate                  HR     chartevents
# 2  220046  Heart rate Alarm - High     HR Alarm - High     chartevents
# 3  220047   Heart Rate Alarm - Low      HR Alarm - Low     chartevents
# 4  220048             Heart Rhythm        Heart Rhythm     chartevents
#
#               category unitname     param_type  lownormalvalue  \
# 0                  ADT      NaN  Date and time             NaN
# 1  Routine Vital Signs      bpm        Numeric             NaN
# 2               Alarms      bpm        Numeric             NaN
# 3               Alarms      bpm        Numeric             NaN
# 4  Routine Vital Signs      NaN           Text             NaN
#
#    highnormalvalue
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %% [markdown]
# Select chart data for subject_id_example

# %%
df_chartevents_subject_id_example = df_chartevents[df_chartevents["subject_id"] == constants.subject_id_example]

# %%
df_chartevents_subject_id_example
# Out:
#           subject_id   hadm_id   stay_id            charttime  \
# 184093      10216097  23709960  38761080  2189-07-03 20:00:00
# 184094      10216097  23709960  38761080  2189-07-03 20:00:00
# 184095      10216097  23709960  38761080  2189-07-03 20:00:00
# 184096      10216097  23709960  38761080  2189-07-03 20:00:00
# 184097      10216097  23709960  38761080  2189-07-03 20:00:00
# ...              ...       ...       ...                  ...
# 13255480    10216097  23709960  38761080  2189-07-10 16:25:00
# 13255481    10216097  23709960  38761080  2189-07-10 16:25:00
# 13255482    10216097  23709960  38761080  2189-07-10 16:25:00
# 13255483    10216097  23709960  38761080  2189-07-10 16:25:00
# 13255484    10216097  23709960  38761080  2189-07-10 16:25:00
#
#                     storetime  itemid    value  valuenum valueuom  warning
# 184093    2189-07-03 21:05:00  220045       57      57.0      bpm        0
# 184094    2189-07-03 21:05:00  220046      130     130.0      bpm        0
# 184095    2189-07-03 21:05:00  220047       50      50.0      bpm        0
# 184096    2189-07-03 21:06:00  220059       61      61.0     mmHg        0
# 184097    2189-07-03 21:06:00  220060       23      23.0     mmHg        0
# ...                       ...     ...      ...       ...      ...      ...
# 13255480  2189-07-10 16:25:00  224011     Soft       NaN      NaN        0
# 13255481  2189-07-10 16:25:00  224012  Commode       NaN      NaN        0
# 13255482  2189-07-10 16:25:00  224794    Brown       NaN      NaN        0
# 13255483  2189-07-10 16:25:00  228013  Grade 0       NaN      NaN        0
# 13255484  2189-07-10 16:25:00  228014  Grade 0       NaN      NaN        0
#
# [5427 rows x 10 columns]

# %%
# 186137  2189-07-10 15:29:00  220045    87      87.0      bpm        0
# 186143  2189-07-10 16:24:00  220045    85      85.0      bpm        0
#
#         Heart Rate
# 184093        57.0
# 184128        54.0
# 184146        77.0
# 184152        71.0
# 184158        83.0
# ...            ...
# 186120        81.0
# 186124        86.0
# 186131        80.0
# 186137        87.0
# 186143        85.0
#
# [169 rows x 11 columns]

# %%
df_chartevents_subject_id_example.dtypes
# Out:
# subject_id      int64
# hadm_id         int64
# stay_id         int64
# charttime      object
# storetime      object
# itemid          int64
# value          object
# valuenum      float64
# valueuom       object
# warning         int64
# Heart Rate    float64
# dtype: object

# %%
df_chartevents_subject_id_example[constants.chart_event_list[0]] = df_chartevents_subject_id_example["valuenum"]
# Out:
# C:\Users\B\AppData\Local\Temp/ipykernel_19528/3814719810.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example[constants.chart_event_list[0]] = df_chartevents_subject_id_example["valuenum"]

# %%
chart_series = df_chartevents_subject_id_example[["stay_id","charttime",constants.chart_event_list[0]]]

# %%
 fc_parameters = {"length": None,
                    "absolute_sum_of_changes": None, 
                    "maximum": None, 
                    "mean": None,
                    "mean_abs_change": None,
                    "mean_change": None,
                    "median": None,
                    "minimum": None,
                    "standard_deviation": None,
                    "variance": None,
                    "large_standard_deviation": [{"r": r * 0.2} for r in range(1, 5)],
                    "quantile": [{"q": q} for q in [.25, .5, .75, 1]],
                    "linear_trend": [{"attr": "pvalue"}, {"attr": "rvalue"}, {"attr": "intercept"},{"attr": "slope"}, {"attr": "stderr"}]}

# %%
chart_extracted_features = extract_features(chart_series, column_id="stay_id", column_sort="charttime", default_fc_parameters=fc_parameters)
# Out:
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.78s/it]

# %%
chart_extracted_features
# Out:
#           Heart Rate__length  Heart Rate__absolute_sum_of_changes  \
# 38761080               169.0                               1400.0
#
#           Heart Rate__maximum  Heart Rate__mean  Heart Rate__mean_abs_change  \
# 38761080                118.0         86.863905                     8.333333
#
#           Heart Rate__mean_change  Heart Rate__median  Heart Rate__minimum  \
# 38761080                 0.166667                88.0                 54.0
#
#           Heart Rate__standard_deviation  Heart Rate__variance  ...  \
# 38761080                       12.433461            154.590946  ...
#
#           Heart Rate__large_standard_deviation__r_0.8  \
# 38761080                                          0.0
#
#           Heart Rate__quantile__q_0.25  Heart Rate__quantile__q_0.5  \
# 38761080                          79.0                         88.0
#
#           Heart Rate__quantile__q_0.75  Heart Rate__quantile__q_1  \
# 38761080                          96.0                      118.0
#
#           Heart Rate__linear_trend__attr_"pvalue"  \
# 38761080                                 0.210892
#
#           Heart Rate__linear_trend__attr_"rvalue"  \
# 38761080                                 0.096732
#
#           Heart Rate__linear_trend__attr_"intercept"  \
# 38761080                                   84.793039
#
#           Heart Rate__linear_trend__attr_"slope"  \
# 38761080                                0.024653
#
#           Heart Rate__linear_trend__attr_"stderr"
# 38761080                                 0.019629
#
# [1 rows x 23 columns]

# %% [markdown]
# #### Lab events example

# %% [markdown]
# Read all data from chartevents and d_items

# %% [markdown]
# labevents dataframe

# %%
df_labevents =read_csv(constants.labevents,low_memory=False, dtype={'storetime': 'object', 'value': 'object', 'valueuom': 'object', 'flag': 'object', 'priority': 'object', 'comments': 'object'}, nrows=20000000)

# %% [markdown]
# d_labitems dataframe

# %%
df_d_labitems = pd.read_csv(constants.d_labitems)

# %%
df_d_labitems
# Out:
#       itemid                      label             fluid    category  \
# 0      51905                             Other Body Fluid   Chemistry
# 1      51532     11-Deoxycorticosterone             Blood   Chemistry
# 2      51957  17-Hydroxycorticosteroids             Urine   Chemistry
# 3      51958     17-Ketosteroids, Urine             Urine   Chemistry
# 4      52068                      24 Hr             Blood  Hematology
# ...      ...                        ...               ...         ...
# 1625   52017                Zinc, Urine             Urine   Chemistry
# 1626   52420                    ZZDUMMY             Urine  Hematology
# 1627   51771                        NaN             Blood   Chemistry
# 1628   51955                        NaN             Stool   Chemistry
# 1629   52374                        NaN  Other Body Fluid  Hematology
#
#      loinc_code
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 1625        NaN
# 1626        NaN
# 1627        NaN
# 1628        NaN
# 1629        NaN
#
# [1630 rows x 5 columns]

# %% [markdown]
# Select lab data for subject_id_example

# %%
df_labevents_subject_id_example = df_labevents[df_labevents["subject_id"] == constants.subject_id_example]

# %%
df_labevents_subject_id_example
# Out:
#           labevent_id  subject_id     hadm_id  specimen_id  itemid  \
# 257948        2603420    10216097         NaN     42503221   50861
# 257949        2603421    10216097         NaN     42503221   50863
# 257950        2603422    10216097         NaN     42503221   50868
# 257951        2603423    10216097         NaN     42503221   50878
# 257952        2603424    10216097         NaN     42503221   50882
# ...               ...         ...         ...          ...     ...
# 12743854      2604751    10216097  23709960.0     32602348   51275
# 12748010      2603658    10216097  23709960.0      4901999   51275
# 12751434      2604508    10216097  23709960.0     69110349   51275
# 12752772      2604863    10216097  23709960.0     69505888   50893
# 12752773      2604867    10216097  23709960.0     69505888   50960
#
#                     charttime            storetime  value  valuenum valueuom  \
# 257948    2189-06-10 17:49:00  2189-06-10 23:10:00     22      22.0     IU/L
# 257949    2189-06-10 17:49:00  2189-06-10 23:10:00    259     259.0     IU/L
# 257950    2189-06-10 17:49:00  2189-06-10 18:52:00     19      19.0    mEq/L
# 257951    2189-06-10 17:49:00  2189-06-10 23:10:00     31      31.0     IU/L
# 257952    2189-06-10 17:49:00  2189-06-10 18:52:00     27      27.0    mEq/L
# ...                       ...                  ...    ...       ...      ...
# 12743854  2189-07-10 04:31:00  2189-07-10 05:30:00  100.9     100.9      sec
# 12748010  2189-06-16 02:47:00  2189-06-16 03:37:00  142.4     142.4      sec
# 12751434  2189-07-04 15:40:00  2189-07-04 16:21:00  131.9     131.9      sec
# 12752772  2189-07-13 07:05:00  2189-07-13 10:07:00      0       0.0    mg/dL
# 12752773  2189-07-13 07:05:00  2189-07-13 10:07:00    0.3       0.3    mg/dL
#
#           ref_range_lower  ref_range_upper      flag priority comments
# 257948                0.0             40.0       NaN     STAT      NaN
# 257949               40.0            130.0  abnormal     STAT      NaN
# 257950                8.0             20.0       NaN     STAT      NaN
# 257951                0.0             40.0       NaN     STAT      NaN
# 257952               22.0             32.0       NaN     STAT      NaN
# ...                   ...              ...       ...      ...      ...
# 12743854             25.0             36.5  abnormal  ROUTINE      ___
# 12748010             25.0             36.5  abnormal  ROUTINE      ___
# 12751434             25.0             36.5  abnormal  ROUTINE      ___
# 12752772              8.4             10.3  abnormal  ROUTINE      ___
# 12752773              1.6              2.6  abnormal  ROUTINE      ___
#
# [1358 rows x 15 columns]

# %%
df_labevents_subject_id_example = df_labevents_subject_id_example[df_labevents_subject_id_example["itemid"].isin\
                                  (df_d_labitems[df_d_labitems["label"] == constants.lab_event_list[0]]["itemid"])]

# %%
df_labevents_subject_id_example
# Out:
#         labevent_id  subject_id     hadm_id  specimen_id  itemid  \
# 258239      2603739    10216097  23709960.0      7802983   50809
# 258881      2604482    10216097  23709960.0     33443350   50809
#
#                   charttime            storetime value  valuenum valueuom  \
# 258239  2189-06-17 13:08:00  2189-06-17 13:11:00   154     154.0    mg/dL
# 258881  2189-07-04 12:38:00  2189-07-04 12:40:00   155     155.0    mg/dL
#
#         ref_range_lower  ref_range_upper      flag priority comments
# 258239             70.0            105.0  abnormal      NaN      NaN
# 258881             70.0            105.0  abnormal      NaN      NaN

# %%
df_labevents_subject_id_example.dtypes
# Out:
# labevent_id          int64
# subject_id           int64
# hadm_id            float64
# specimen_id          int64
# itemid               int64
# charttime           object
# storetime           object
# value               object
# valuenum           float64
# valueuom            object
# ref_range_lower    float64
# ref_range_upper    float64
# flag                object
# priority            object
# comments            object
# dtype: object

# %%
df_labevents_subject_id_example[constants.lab_event_list[0]] = df_labevents_subject_id_example["valuenum"]
# Out:
# C:\Users\B\AppData\Local\Temp/ipykernel_19528/814273413.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example[constants.lab_event_list[0]] = df_labevents_subject_id_example["valuenum"]

# %%
df_labevents_subject_id_example
# Out:
#         labevent_id  subject_id     hadm_id  specimen_id  itemid  \
# 258239      2603739    10216097  23709960.0      7802983   50809
# 258881      2604482    10216097  23709960.0     33443350   50809
#
#                   charttime            storetime value  valuenum valueuom  \
# 258239  2189-06-17 13:08:00  2189-06-17 13:11:00   154     154.0    mg/dL
# 258881  2189-07-04 12:38:00  2189-07-04 12:40:00   155     155.0    mg/dL
#
#         ref_range_lower  ref_range_upper      flag priority comments  Glucose
# 258239             70.0            105.0  abnormal      NaN      NaN    154.0
# 258881             70.0            105.0  abnormal      NaN      NaN    155.0

# %%
lab_series = df_labevents_subject_id_example[["hadm_id","charttime",constants.lab_event_list[0]]]

# %%
lab_extracted_features = extract_features(lab_series, column_id="hadm_id", column_sort="charttime", default_fc_parameters=fc_parameters)
# Out:
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.76s/it]

# %%
lab_extracted_features
# Out:
#             Glucose__length  Glucose__absolute_sum_of_changes  \
# 23709960.0              2.0                               1.0
#
#             Glucose__maximum  Glucose__mean  Glucose__mean_abs_change  \
# 23709960.0             155.0          154.5                       1.0
#
#             Glucose__mean_change  Glucose__median  Glucose__minimum  \
# 23709960.0                   1.0            154.5             154.0
#
#             Glucose__standard_deviation  Glucose__variance  ...  \
# 23709960.0                          0.5               0.25  ...
#
#             Glucose__large_standard_deviation__r_0.8  \
# 23709960.0                                       0.0
#
#             Glucose__quantile__q_0.25  Glucose__quantile__q_0.5  \
# 23709960.0                     154.25                     154.5
#
#             Glucose__quantile__q_0.75  Glucose__quantile__q_1  \
# 23709960.0                     154.75                   155.0
#
#             Glucose__linear_trend__attr_"pvalue"  \
# 23709960.0                                   0.0
#
#             Glucose__linear_trend__attr_"rvalue"  \
# 23709960.0                                   1.0
#
#             Glucose__linear_trend__attr_"intercept"  \
# 23709960.0                                    154.0
#
#             Glucose__linear_trend__attr_"slope"  \
# 23709960.0                                  1.0
#
#             Glucose__linear_trend__attr_"stderr"
# 23709960.0                                   0.0
#
# [1 rows x 23 columns]

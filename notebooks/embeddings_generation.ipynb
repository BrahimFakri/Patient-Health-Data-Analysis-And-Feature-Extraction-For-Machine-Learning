# %% [markdown]
# ### Imports

# %%
import os
os.chdir('../')

from src.data import constants
import pandas as pd
from pandas import read_csv
import datetime as dt
import numpy as np

# %% [markdown]
# ### Read data from local source

# %% [markdown]
# MIMIC-IV Dataset

# %% [markdown]
# Core

# %%
df_admissions = read_csv(constants.admissions)
df_patients = read_csv(constants.patients)
df_transfers = read_csv(constants.transfers)

# %%
df_admissions
# Out:
#         subject_id   hadm_id            admittime            dischtime  \
# 0         14679932  21038362  2139-09-26 14:16:00  2139-09-28 11:30:00
# 1         15585972  24941086  2123-10-07 23:56:00  2123-10-12 11:22:00
# 2         11989120  21965160  2147-01-14 09:00:00  2147-01-17 14:25:00
# 3         17817079  24709883  2165-12-27 17:33:00  2165-12-31 21:18:00
# 4         15078341  23272159  2122-08-28 08:48:00  2122-08-30 12:32:00
# ...            ...       ...                  ...                  ...
# 523735    17892964  20786062  2180-09-17 00:00:00  2180-09-18 13:37:00
# 523736    17137572  20943099  2147-08-01 17:41:00  2147-08-02 17:30:00
# 523737    19389857  23176714  2189-03-01 00:58:00  2189-03-02 15:22:00
# 523738    12298845  22347500  2138-05-31 00:00:00  2138-06-04 16:50:00
# 523739    11211939  24981356  2147-08-02 15:49:00  2147-08-05 16:30:00
#
#        deathtime               admission_type      admission_location  \
# ...

# %%
len(df_admissions["subject_id"].unique())
# Out:
# 256878

# %%
len(df_admissions["hadm_id"].unique())
# Out:
# 523740

# %%
len(df_transfers["subject_id"].unique())
# Out:
# 382278

# %%
df_transfers
# Out:
#          subject_id     hadm_id  transfer_id  eventtype              careunit  \
# 0          14550633  24512724.0     35906369      admit                   NaN
# 1          15216953  25759433.0     37381511      admit                   NaN
# 2          15776555  28490372.0     34638843      admit                   NaN
# 3          12248661  23426497.0     39272104  discharge                   NaN
# 4          14261068  20086032.0     36182135  discharge                   NaN
# ...             ...         ...          ...        ...                   ...
# 2189530    13152507         NaN     31291209         ED  Emergency Department
# 2189531    13575285         NaN     30468102         ED  Emergency Department
# 2189532    16414198  20282129.0     33660494      admit                   NaN
# 2189533    15596627  26100831.0     31161088      admit                   NaN
# 2189534    12227693  25565517.0     38464388      admit                   NaN
#
# ...

# %%
len(df_transfers["hadm_id"].unique())
# Out:
# 523741

# %% [markdown]
# HOSP

# %%
df_d_labitems = read_csv(constants.d_labitems, nrows=20)
df_d_icd_procedures = read_csv(constants.d_icd_procedures, nrows=20)
df_d_icd_diagnoses = read_csv(constants.d_icd_diagnoses, nrows=20)
df_d_hcpcs = read_csv(constants.d_hcpcs, nrows=20)
df_diagnoses_icd = read_csv(constants.diagnoses_icd, nrows=20)
df_drgcodes = read_csv(constants.drgcodes, nrows=20)
df_emar = read_csv(constants.emar, nrows=20)
df_emar_detail = read_csv(constants.emar_detail, nrows=20)
df_hcpcsevents = read_csv(constants.hcpcsevents, nrows=20)
df_labevents = read_csv(constants.labevents, nrows=20)
df_microbiologyevents = read_csv(constants.microbiologyevents, nrows=20)
df_poe = read_csv(constants.poe, nrows=20)
df_poe_detail = read_csv(constants.poe_detail, nrows=20)
df_prescriptions = read_csv(constants.prescriptions, nrows=20)
df_procedures_icd = read_csv(constants.procedures_icd, nrows=20)
df_services = read_csv(constants.services, nrows=20)
df_pharmacy = read_csv(constants.pharmacy, nrows=20)

# %% [markdown]
# ICU

# %%
df_d_items = read_csv(constants.d_items, nrows=20000)
df_procedureevents = read_csv(constants.procedureevents, nrows=20000)
df_outputevents = read_csv(constants.outputevents, nrows=20000)
df_inputevents = read_csv(constants.inputevents, nrows=20000)
df_icustays = read_csv(constants.icustays, nrows=20000)
df_datetimeevents = read_csv(constants.datetimeevents, nrows=20000)
df_chartevents = read_csv(constants.chartevents, nrows=20000)

# %%
print(df_d_items.columns,"\n**************************************\n", df_procedureevents.columns,"\n**************************************\n",df_outputevents.columns,"\n**************************************\n",df_inputevents.columns,"\n**************************************\n",df_icustays.columns,"\n**************************************\n",df_datetimeevents.columns,"\n**************************************\n",df_chartevents.columns,"\n**************************************\n",)
# Out:
# Index(['itemid', 'label', 'abbreviation', 'linksto', 'category', 'unitname',
#        'param_type', 'lownormalvalue', 'highnormalvalue'],
#       dtype='object')
# **************************************
#  Index(['subject_id', 'hadm_id', 'stay_id', 'starttime', 'endtime', 'storetime',
#        'itemid', 'value', 'valueuom', 'location', 'locationcategory',
#        'orderid', 'linkorderid', 'ordercategoryname',
#        'secondaryordercategoryname', 'ordercategorydescription',
#        'patientweight', 'totalamount', 'totalamountuom', 'isopenbag',
#        'continueinnextdept', 'cancelreason', 'statusdescription',
#        'comments_date', 'originalamount', 'originalrate'],
#       dtype='object')
# **************************************
#  Index(['subject_id', 'hadm_id', 'stay_id', 'charttime', 'storetime', 'itemid',
#        'value', 'valueuom'],
#       dtype='object')
# **************************************
# ...

# %% [markdown]
# MIMIC-CXR Dataset

# %%
df_mimic_cxr_chexpert = read_csv(constants.mimic_cxr_chexpert)
df_mimic_cxr_metadata = read_csv(constants.mimic_cxr_metadata)

# %%
df_patients.columns

# %%
df_admissions.columns

# %%
df_transfers.columns

# %%
df_mimic_cxr_chexpert.columns
# Out:
# Index(['subject_id', 'study_id', 'Atelectasis', 'Cardiomegaly',
#        'Consolidation', 'Edema', 'Enlarged Cardiomediastinum', 'Fracture',
#        'Lung Lesion', 'Lung Opacity', 'No Finding', 'Pleural Effusion',
#        'Pleural Other', 'Pneumonia', 'Pneumothorax', 'Support Devices'],
#       dtype='object')

# %%
df_mimic_cxr_chexpert
# Out:
#         subject_id  study_id  Atelectasis  Cardiomegaly  Consolidation  Edema  \
# 0         10000032  50414267          NaN           NaN            NaN    NaN
# 1         10000032  53189527          NaN           NaN            NaN    NaN
# 2         10000032  53911762          NaN           NaN            NaN    NaN
# 3         10000032  56699142          NaN           NaN            NaN    NaN
# 4         10000764  57375967          NaN           NaN            1.0    NaN
# ...            ...       ...          ...           ...            ...    ...
# 227822    19999442  58708861          NaN           NaN            NaN    NaN
# 227823    19999733  57132437          NaN           NaN            NaN    NaN
# 227824    19999987  55368167          1.0          -1.0            NaN    NaN
# 227825    19999987  58621812          1.0           NaN            NaN    NaN
# 227826    19999987  58971208          1.0           NaN            NaN    NaN
#
# ...

# %%
df_mimic_cxr_metadata.columns
# Out:
# Index(['dicom_id', 'subject_id', 'study_id',
#        'PerformedProcedureStepDescription', 'ViewPosition', 'Rows', 'Columns',
#        'StudyDate', 'StudyTime', 'ProcedureCodeSequence_CodeMeaning',
#        'ViewCodeSequence_CodeMeaning',
#        'PatientOrientationCodeSequence_CodeMeaning'],
#       dtype='object')

# %%
df_mimic_cxr_metadata
# Out:
#                                             dicom_id  subject_id  study_id  \
# 0       02aa804e-bde0afdd-112c0b34-7bc16630-4e384014    10000032  50414267
# 1       174413ec-4ec4c1f7-34ea26b7-c5f994f8-79ef1962    10000032  50414267
# 2       2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab    10000032  53189527
# 3       e084de3b-be89b11e-20fe3f9f-9c8d8dfe-4cfd202c    10000032  53189527
# 4       68b5c4b1-227d0485-9cc38c3f-7b84ab51-4b472714    10000032  53911762
# ...                                              ...         ...       ...
# 377105  428e2c18-5721d8f3-35a05001-36f3d080-9053b83c    19999733  57132437
# 377106  58c403aa-35ff8bd9-73e39f54-8dc9cc5d-e0ec3fa9    19999733  57132437
# 377107  58766883-376a15ce-3b323a28-6af950a0-16b793bd    19999987  55368167
# 377108  7ba273af-3d290f8d-e28d0ab4-484b7a86-7fc12b08    19999987  58621812
# 377109  1a1fe7e3-cbac5d93-b339aeda-86bb86b5-4f31e82e    19999987  58971208
#
# ...

# %%
CXRMEGED = df_mimic_cxr_chexpert.merge(df_mimic_cxr_metadata, on= ('subject_id', 'study_id'))

# %%
CXRMEGED
# Out:
#         subject_id  study_id  Atelectasis  Cardiomegaly  Consolidation  Edema  \
# 0         10000032  50414267          NaN           NaN            NaN    NaN
# 1         10000032  50414267          NaN           NaN            NaN    NaN
# 2         10000032  53189527          NaN           NaN            NaN    NaN
# 3         10000032  53189527          NaN           NaN            NaN    NaN
# 4         10000032  53911762          NaN           NaN            NaN    NaN
# ...            ...       ...          ...           ...            ...    ...
# 377090    19999733  57132437          NaN           NaN            NaN    NaN
# 377091    19999733  57132437          NaN           NaN            NaN    NaN
# 377092    19999987  55368167          1.0          -1.0            NaN    NaN
# 377093    19999987  58621812          1.0           NaN            NaN    NaN
# 377094    19999987  58971208          1.0           NaN            NaN    NaN
#
# ...

# %%
df_base_big = df_admissions.merge(df_patients, on=("subject_id")).merge(df_transfers, on=('subject_id', 'hadm_id'))

# %%
df_base_big
# Out:
#          subject_id   hadm_id            admittime            dischtime  \
# 0          14679932  21038362  2139-09-26 14:16:00  2139-09-28 11:30:00
# 1          14679932  21038362  2139-09-26 14:16:00  2139-09-28 11:30:00
# 2          15585972  24941086  2123-10-07 23:56:00  2123-10-12 11:22:00
# 3          15585972  24941086  2123-10-07 23:56:00  2123-10-12 11:22:00
# 4          11989120  21965160  2147-01-14 09:00:00  2147-01-17 14:25:00
# ...             ...       ...                  ...                  ...
# 1840950    14582634  24338797  2170-04-17 23:23:00  2170-04-21 14:22:00
# 1840951    14582634  24338797  2170-04-17 23:23:00  2170-04-21 14:22:00
# 1840952    19389857  23176714  2189-03-01 00:58:00  2189-03-02 15:22:00
# 1840953    19389857  23176714  2189-03-01 00:58:00  2189-03-02 15:22:00
# 1840954    19389857  23176714  2189-03-01 00:58:00  2189-03-02 15:22:00
#
#         deathtime               admission_type  admission_location  \
# ...

# %%
df_base_GIGANTIC = df_base_big.merge(df_icustays, on=('subject_id', 'hadm_id'))

# %%
df_base_GIGANTIC
# Out:
#         subject_id   hadm_id            admittime            dischtime  \
# 0         15772648  23693642  2146-02-15 13:56:00  2146-02-20 17:30:00
# 1         15772648  23693642  2146-02-15 13:56:00  2146-02-20 17:30:00
# 2         15772648  23693642  2146-02-15 13:56:00  2146-02-20 17:30:00
# 3         15772648  23693642  2146-02-15 13:56:00  2146-02-20 17:30:00
# 4         15772648  26147926  2146-06-18 17:19:00  2146-06-23 13:27:00
# ...            ...       ...                  ...                  ...
# 109647    16148446  20856279  2158-02-18 00:48:00  2158-02-21 17:10:00
# 109648    16148446  20856279  2158-02-18 00:48:00  2158-02-21 17:10:00
# 109649    10847171  21303608  2154-08-18 01:55:00  2154-08-19 10:40:00
# 109650    10847171  21303608  2154-08-18 01:55:00  2154-08-19 10:40:00
# 109651    10847171  21303608  2154-08-18 01:55:00  2154-08-19 10:40:00
#
#        deathtime               admission_type  admission_location  \
# ...

# %%
DFMEGATRON = df_base_GIGANTIC.merge(CXRMEGED, on=("subject_id"))

# %%
DFMEGATRON
# Out:
#         subject_id   hadm_id            admittime            dischtime  \
# 0         16296962  29416427  2163-01-12 17:53:00  2163-01-18 16:00:00
# 1         16296962  29416427  2163-01-12 17:53:00  2163-01-18 16:00:00
# 2         16296962  29416427  2163-01-12 17:53:00  2163-01-18 16:00:00
# 3         16296962  29416427  2163-01-12 17:53:00  2163-01-18 16:00:00
# 4         16296962  29035203  2163-06-13 07:15:00  2163-06-18 16:28:00
# ...            ...       ...                  ...                  ...
# 876335    17520318  23431795  2170-02-28 03:40:00  2170-03-20 03:30:00
# 876336    16148446  20856279  2158-02-18 00:48:00  2158-02-21 17:10:00
# 876337    16148446  20856279  2158-02-18 00:48:00  2158-02-21 17:10:00
# 876338    16148446  20856279  2158-02-18 00:48:00  2158-02-21 17:10:00
# 876339    16148446  20856279  2158-02-18 00:48:00  2158-02-21 17:10:00
#
#                   deathtime               admission_type  admission_location  \
# ...

# %%
DFMEGATRON.drop_duplicates()
# Out:
#         subject_id   hadm_id            admittime            dischtime  \
# 0         16296962  29416427  2163-01-12 17:53:00  2163-01-18 16:00:00
# 1         16296962  29416427  2163-01-12 17:53:00  2163-01-18 16:00:00
# 2         16296962  29416427  2163-01-12 17:53:00  2163-01-18 16:00:00
# 3         16296962  29416427  2163-01-12 17:53:00  2163-01-18 16:00:00
# 4         16296962  29035203  2163-06-13 07:15:00  2163-06-18 16:28:00
# ...            ...       ...                  ...                  ...
# 876335    17520318  23431795  2170-02-28 03:40:00  2170-03-20 03:30:00
# 876336    16148446  20856279  2158-02-18 00:48:00  2158-02-21 17:10:00
# 876337    16148446  20856279  2158-02-18 00:48:00  2158-02-21 17:10:00
# 876338    16148446  20856279  2158-02-18 00:48:00  2158-02-21 17:10:00
# 876339    16148446  20856279  2158-02-18 00:48:00  2158-02-21 17:10:00
#
#                   deathtime               admission_type  admission_location  \
# ...

# %%
DFMEGATRON.columns
# Out:
# Index(['subject_id', 'hadm_id', 'admittime', 'dischtime', 'deathtime',
#        'admission_type', 'admission_location', 'discharge_location',
#        'insurance', 'language', 'marital_status', 'ethnicity', 'edregtime',
#        'edouttime', 'hospital_expire_flag', 'gender', 'anchor_age',
#        'anchor_year', 'anchor_year_group', 'dod', 'transfer_id', 'eventtype',
#        'careunit', 'intime_x', 'outtime_x', 'stay_id', 'first_careunit',
#        'last_careunit', 'intime_y', 'outtime_y', 'los', 'study_id',
#        'Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema',
#        'Enlarged Cardiomediastinum', 'Fracture', 'Lung Lesion', 'Lung Opacity',
#        'No Finding', 'Pleural Effusion', 'Pleural Other', 'Pneumonia',
#        'Pneumothorax', 'Support Devices', 'dicom_id',
#        'PerformedProcedureStepDescription', 'ViewPosition', 'Rows', 'Columns',
#        'StudyDate', 'StudyTime', 'ProcedureCodeSequence_CodeMeaning',
#        'ViewCodeSequence_CodeMeaning',
# ...

# %% [markdown]
# #### GET LIST OF ALL UNIQUE ID COMBINATIONS IN MIMIC-IV (subject_id, hadm_id, stay_id)

# %%
df_base_core = df_admissions.merge(df_patients, how='left').merge(df_transfers, how='left')

# %%
df_base_core.columns

# %%
# Get Unique Subject/HospAdmission/Stay Combinations
df_ids = pd.concat([pd.DataFrame(), df_procedureevents[['subject_id','hadm_id','stay_id']]], sort=False).drop_duplicates()
df_ids = pd.concat([df_ids, df_outputevents[['subject_id','hadm_id','stay_id']]], sort=False).drop_duplicates()
df_ids = pd.concat([df_ids, df_inputevents[['subject_id','hadm_id','stay_id']]], sort=False).drop_duplicates()
df_ids = pd.concat([df_ids, df_icustays[['subject_id','hadm_id','stay_id']]], sort=False).drop_duplicates()
df_ids = pd.concat([df_ids, df_datetimeevents[['subject_id','hadm_id','stay_id']]], sort=False).drop_duplicates()
df_ids = pd.concat([df_ids, df_chartevents[['subject_id','hadm_id','stay_id']]], sort=True).drop_duplicates()

# Get Unique Subjects with Chest Xrays
df_cxr_ids = pd.concat([pd.DataFrame(), df_mimic_cxr_chexpert[['subject_id']]], sort=True).drop_duplicates()

# Get Unique Subject/HospAdmission/Stay Combinations with Chest Xrays
df_haim_ids = df_ids[df_ids['subject_id'].isin(df_cxr_ids['subject_id'].unique())]

# %%
df_ids

# %%
df_cxr_ids

# %%
df_haim_ids

# %%
# Save Unique Subject/HospAdmission/Stay Combinations with Chest Xrays    
#df_haim_ids.to_csv('/home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-1.0/haim_mimiciv_key_ids.csv', index=False)

# %%
df_d_items = read_csv(constants.d_items, nrows=20)
df_procedureevents = read_csv(constants.procedureevents, nrows=20)
df_outputevents = read_csv(constants.outputevents, nrows=20)
df_inputevents = read_csv(constants.inputevents, nrows=20)
df_icustays = read_csv(constants.icustays, nrows=20)
df_datetimeevents = read_csv(constants.datetimeevents, nrows=20)
df_chartevents = read_csv(constants.chartevents, nrows=20)

# %%
df_mimic_cxr_metadata

# %%
ligne = df_mimic_cxr_metadata.loc[df_mimic_cxr_metadata['dicom_id'] == "0179407d-0928478c-d6d8014a-59a50b89-cdc9edc5"]

# %%
ligne

# %%
ligne2 = df_mimic_cxr_metadata.loc[df_mimic_cxr_metadata['subject_id'] == 10088198] 
ligne2.shape

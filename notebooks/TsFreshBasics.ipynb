# %%
# !pip show tsfresh
# Out:
# Name: tsfresh
# Version: 0.20.0
# Summary: tsfresh extracts relevant characteristics from time series
# Home-page: https://github.com/blue-yonder/tsfresh
# Author: Maximilian Christ, Nils Braun, Julius Neuffer, Andreas W. Kempa-Liehr
# Author-email: max.christ@me.com
# License: MIT
# Location: /home/local/USHERBROOKE/fakb2301/anaconda3/lib/python3.9/site-packages
# Requires: cloudpickle, dask, distributed, numpy, pandas, patsy, requests, scikit-learn, scipy, statsmodels, stumpy, tqdm
# Required-by:

# %%
import tsfresh

# %%
from tsfresh.examples.robot_execution_failures import download_robot_execution_failures, \
    load_robot_execution_failures
download_robot_execution_failures()
timeseries, y = load_robot_execution_failures()

# %%
timeseries
# Out:
#       id  time  F_x  F_y  F_z  T_x  T_y  T_z
# 0      1     0   -1   -1   63   -3   -1    0
# 1      1     1    0    0   62   -3   -1    0
# 2      1     2   -1   -1   61   -3    0    0
# 3      1     3   -1   -1   63   -2   -1    0
# 4      1     4   -1   -1   63   -3   -1    0
# ...   ..   ...  ...  ...  ...  ...  ...  ...
# 1315  88    10  -10    2   39  -21  -24    5
# 1316  88    11  -11    2   38  -24  -22    6
# 1317  88    12  -12    3   23  -24  -24    5
# 1318  88    13  -13    4   26  -29  -27    5
# 1319  88    14  -13    2   15  -25  -25    6
#
# [1320 rows x 8 columns]

# %%
y
# Out:
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
#       ...
# 84    False
# 85    False
# 86    False
# 87    False
# 88    False
# Length: 88, dtype: bool

# %%
print(timeseries.head())
# Out:
#    id  time  F_x  F_y  F_z  T_x  T_y  T_z
# 0   1     0   -1   -1   63   -3   -1    0
# 1   1     1    0    0   62   -3   -1    0
# 2   1     2   -1   -1   61   -3    0    0
# 3   1     3   -1   -1   63   -2   -1    0
# 4   1     4   -1   -1   63   -3   -1    0

# %%
timeseries[timeseries['id'] == 3]
# Out:
#     id  time  F_x  F_y  F_z  T_x  T_y  T_z
# 30   3     0   -1    0   57   -5   -3    0
# 31   3     1    0   -3   63   -1    0    0
# 32   3     2   -1    1   51   -4   -1   -1
# 33   3     3   -1   -2   68   -2   -2    0
# 34   3     4   -1   -1   65   -6    1    0
# 35   3     5    0    0   61   -5   -2    0
# 36   3     6   -1    1   61   -6    0   -1
# 37   3     7    0   -3   57    3   -4    0
# 38   3     8   -1   -1   59   -4   -4    0
# 39   3     9    1   -3   65   -1    1    0
# 40   3    10   -1    2   64   -7   -2    0
# 41   3    11   -1    1   66   -7   -3   -1
# 42   3    12   -1    0   61   -5   -5    0
# 43   3    13   -1    0   65   -6   -2   -1
# 44   3    14   -1    0   54   -4   -3    0

# %%
import matplotlib.pyplot as plt
timeseries[timeseries['id'] == 3].plot(subplots=True, sharex=True, figsize=(10,10))
plt.show()

# %%
fc_parameters = {"large_standard_deviation": [{"r": 0.05}, {"r": 0.1}]}

# %%
from tsfresh import extract_features
extracted_features = extract_features(timeseries, column_id="id", column_sort="time", default_fc_parameters=fc_parameters)
# Out:
# Feature Extraction: 100%|██████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 1195.28it/s]

# %%
extracted_features
# Out:
#     F_x__large_standard_deviation__r_0.05  \
# 1                                     1.0
# 2                                     1.0
# 3                                     1.0
# 4                                     1.0
# 5                                     1.0
# ..                                    ...
# 84                                    1.0
# 85                                    1.0
# 86                                    1.0
# 87                                    1.0
# 88                                    1.0
#
#     F_x__large_standard_deviation__r_0.1  \
# 1                                    1.0
# 2                                    1.0
# 3                                    1.0
# 4                                    1.0
# 5                                    1.0
# ..                                   ...
# 84                                   1.0
# 85                                   1.0
# 86                                   1.0
# ...

# %%
fc_parameters = {
    "length": None,
    "large_standard_deviation": [{"r": 0.05}]
}

# %%
from tsfresh import extract_features
extracted_features = extract_features(timeseries, column_id="id", column_sort="time", default_fc_parameters=fc_parameters)
# Out:
# Feature Extraction: 100%|██████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 1322.52it/s]

# %%
extracted_features
# Out:
#     F_x__length  F_x__large_standard_deviation__r_0.05  F_y__length  \
# 1          15.0                                    1.0         15.0
# 2          15.0                                    1.0         15.0
# 3          15.0                                    1.0         15.0
# 4          15.0                                    1.0         15.0
# 5          15.0                                    1.0         15.0
# ..          ...                                    ...          ...
# 84         15.0                                    1.0         15.0
# 85         15.0                                    1.0         15.0
# 86         15.0                                    1.0         15.0
# 87         15.0                                    1.0         15.0
# 88         15.0                                    1.0         15.0
#
#     F_y__large_standard_deviation__r_0.05  F_z__length  \
# 1                                     1.0         15.0
# ...

# %% [markdown]
# ### All 783 extracted features

# %%
from tsfresh import extract_features
extracted_features = extract_features(timeseries, column_id="id", column_sort="time")
extracted_features
# Out:
# Feature Extraction: 100%|████████████████████████████████████████████████████████████████| 59/59 [00:01<00:00, 41.61it/s]
#     T_x__variance_larger_than_standard_deviation  T_x__has_duplicate_max  \
# 1                                            0.0                     1.0
# 2                                            1.0                     1.0
# 3                                            1.0                     0.0
# 4                                            1.0                     1.0
# 5                                            1.0                     0.0
# ..                                           ...                     ...
# 84                                           1.0                     0.0
# 85                                           1.0                     0.0
# 86                                           1.0                     0.0
# 87                                           1.0                     0.0
# ...

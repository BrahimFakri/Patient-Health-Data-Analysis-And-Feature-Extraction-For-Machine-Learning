# %% [markdown]
# The goal of this notebook is to use the methods in the module ```extraction_classes.py``` and the datasources in ```csv``` to generate demographic and time series embeddings.
#
# in the first cell, we import all constants and modules necessary for this notebook, then in the following cells, we create dataframes from extracted features using the functions mentionned above.
#
# And finally, we concatenate the dataframe to create our fusion dataframe to be used in machine learning.
#
# Note: in this notebook, we only use a cohort of 10 patients to make the data processing and extraction easier for our tests. Objects from classes are intantiated  inside each extraction line. For example:
#
# ``extraction_classes.Event_extraction(patient).extract_chart_events(patient)`` in this code, the loop creates an object ``Event_extraction`` for each ``patient`` in the cohort and apllies the method  ``extract_chart_events``.
#
#
# To generate embeddings for all patients, more processing time is required, especially for time series feature extraction.

# %% [markdown]
# ### Imports

# %%
import os
os.chdir('../..')

from src.data import constants
from src.utils import extraction_classes

import pandas as pd

# %% [markdown]
# ## Create chart events features for patient cohort

# %% [markdown]
# Start by creating an empty list that will be filled with the extracted features for chart events:

# %%
chart_fusion = []
for patient in constants.cohort:

    chart_fusion.append(extraction_classes.Event_extraction(patient).extract_chart_events(patient))
# Out:
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.49s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.49s/it]
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.06s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.84s/it]
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.84s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.91s/it]
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.50s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.79s/it]
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.20s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.69s/it]
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.59s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.84s/it]
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.09s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.69s/it]
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.25s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.41s/it]
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.83s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.66s/it]
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.15s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.48s/it]

# %% [markdown]
# ### Concatenate chart events fusion features

# %% [markdown]
# Concatenate features along the 0 axis for all patients:

# %%
chart_fusion = pd.concat(chart_fusion, axis=0)

# %% [markdown]
# ## Create lab events features for patient cohort

# %% [markdown]
# Start by creating an empty list that will be filled with the extracted features for lab events:

# %%
lab_fusion = []
for patient in constants.cohort:
    
    lab_fusion.append(extraction_classes.Event_extraction(patient).extract_lab_events(patient))
# Out:
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.59s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.90s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.91s/it]
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.32s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.96s/it]
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.27s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.81s/it]
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.57s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.94s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.94s/it]
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.65s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.94s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.79s/it]
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.33s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.16s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.21s/it]
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.70s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  4.00s/it]
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.41s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.84s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.71s/it]
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.86s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.30s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.90s/it]
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.30s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.81s/it]

# %% [markdown]
# ### Concatenate lab events fusion features

# %% [markdown]
# Concatenate features along the 0 axis for all patients:

# %%
lab_fusion = pd.concat(lab_fusion, axis=0)

# %% [markdown]
# ## Create procedure events features for patient cohort

# %% [markdown]
# Start by creating an empty list that will be filled with the extracted features for procedure events:

# %%
procedure_fusion = []
for patient in constants.cohort:
   
    procedure_fusion.append(extraction_classes.Event_extraction(patient).extract_procedure_events(patient))
# Out:
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_procedureevents_subject_id_example_events[i][constants.procedure_event_list[i]] = df_procedureevents_subject_id_example_events[i]["value"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.53s/it]
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_procedureevents_subject_id_example_events[i][constants.procedure_event_list[i]] = df_procedureevents_subject_id_example_events[i]["value"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.93s/it]
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_procedureevents_subject_id_example_events[i][constants.procedure_event_list[i]] = df_procedureevents_subject_id_example_events[i]["value"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.87s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.59s/it]
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_procedureevents_subject_id_example_events[i][constants.procedure_event_list[i]] = df_procedureevents_subject_id_example_events[i]["value"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.95s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.60s/it]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.81s/it]
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_procedureevents_subject_id_example_events[i][constants.procedure_event_list[i]] = df_procedureevents_subject_id_example_events[i]["value"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.18s/it]
# C:\Users\B\Desktop\fresh start\src\utils\extraction_classes.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_procedureevents_subject_id_example_events[i][constants.procedure_event_list[i]] = df_procedureevents_subject_id_example_events[i]["value"]
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.99s/it]

# %% [markdown]
# ### Concatenate procedure events fusion features

# %% [markdown]
# Concatenate features along the 0 axis for all patients:

# %%
procedure_fusion = pd.concat(procedure_fusion, axis=0)

# %% [markdown]
# ## Create demographic features for patient cohort

# %% [markdown]
# Create and object `Demographic_extraction` and call medthod `extract_demographics` :

# %%
demographics_fusion = extraction_classes.Demographic_extraction().extract_demographics()

# %% [markdown]
# Filter dataframe using patients in the `cohort`:

# %%
demographics_fusion = demographics_fusion[demographics_fusion['subject_id'].isin(constants.cohort)]

# %% [markdown]
# # Concatenate fusion features horizontally for all patients

# %% [markdown]
# Concatenate the generated dataframes to combine  all features

# %%
fusion_dataframe = pd.concat([demographics_fusion, chart_fusion, lab_fusion, procedure_fusion ], axis=1)

# %%
fusion_dataframe = pd.concat([chart_fusion, lab_fusion, procedure_fusion ], axis=1)

# %%
fusion_dataframe
# Out:
#           Heart Rate__length  Heart Rate__absolute_sum_of_changes  \
# 10004235               121.0                                694.0
# 10004720               142.0                                836.0
# 10019003               267.0                                759.0
# 10020852                43.0                                235.0
# 10023708                59.0                                268.0
# 10031358                20.0                                103.0
# 10035631               364.0                               1268.0
# 10046166                23.0                                100.0
# 10047172                45.0                                193.0
# 10051990                52.0                                132.0
#
#           Heart Rate__maximum  Heart Rate__mean  Heart Rate__mean_abs_change  \
# 10004235                144.0        113.115702                     5.783333
# 10004720                122.0         83.119718                     5.929078
# 10019003                128.0         88.277154                     2.853383
# 10020852                 93.0         72.418605                     5.595238
# 10023708                 88.0         71.745763                     4.620690
# 10031358                 91.0         73.450000                     5.421053
# 10035631                174.0        107.332418                     3.493113
# 10046166                 71.0         56.173913                     4.545455
# 10047172                 93.0         79.288889                     4.386364
# 10051990                100.0         91.980769                     2.588235
#
#           Heart Rate__mean_change  Heart Rate__median  Heart Rate__minimum  \
# 10004235                -0.183333               112.0                 87.0
# 10004720                -0.553191                78.0                  0.0
# 10019003                -0.086466                83.0                 69.0
# 10020852                -0.500000                71.0                 56.0
# 10023708                -0.275862                73.0                 58.0
# 10031358                -0.157895                73.0                 58.0
# 10035631                -0.044077               103.0                 81.0
# 10046166                 0.363636                55.0                 46.0
# 10047172                -0.113636                80.0                 65.0
# 10051990                -0.156863                92.0                 85.0
#
#           Heart Rate__standard_deviation  Heart Rate__variance  ...  \
# 10004235                       10.262014            105.308927  ...
# 10004720                       18.472851            341.246231  ...
# 10019003                       13.545525            183.481238  ...
# 10020852                        8.521471             72.615468  ...
# 10023708                        7.240641             52.426889  ...
# 10031358                       10.947488            119.847500  ...
# 10035631                       14.921109            222.639499  ...
# 10046166                        6.862958             47.100189  ...
# 10047172                        9.130224             83.360988  ...
# 10051990                        3.422158             11.711169  ...
#
#           Intubation__large_standard_deviation__r_0.8  \
# 10004235                                          NaN
# 10004720                                          NaN
# 10019003                                          NaN
# 10020852                                          NaN
# 10023708                                          NaN
# 10031358                                          NaN
# 10035631                                          0.0
# 10046166                                          NaN
# 10047172                                          NaN
# 10051990                                          NaN
#
#           Intubation__quantile__q_0.25  Intubation__quantile__q_0.5  \
# 10004235                           NaN                          NaN
# 10004720                           NaN                          NaN
# 10019003                           NaN                          NaN
# 10020852                           NaN                          NaN
# 10023708                           NaN                          NaN
# 10031358                           NaN                          NaN
# 10035631                           1.0                          1.0
# 10046166                           NaN                          NaN
# 10047172                           NaN                          NaN
# 10051990                           NaN                          NaN
#
#           Intubation__quantile__q_0.75  Intubation__quantile__q_1  \
# 10004235                           NaN                        NaN
# 10004720                           NaN                        NaN
# 10019003                           NaN                        NaN
# 10020852                           NaN                        NaN
# 10023708                           NaN                        NaN
# 10031358                           NaN                        NaN
# 10035631                           1.0                        1.0
# 10046166                           NaN                        NaN
# 10047172                           NaN                        NaN
# 10051990                           NaN                        NaN
#
#           Intubation__linear_trend__attr_"pvalue"  \
# 10004235                                      NaN
# 10004720                                      NaN
# 10019003                                      NaN
# 10020852                                      NaN
# 10023708                                      NaN
# 10031358                                      NaN
# 10035631                                      NaN
# 10046166                                      NaN
# 10047172                                      NaN
# 10051990                                      NaN
#
#           Intubation__linear_trend__attr_"rvalue"  \
# 10004235                                      NaN
# 10004720                                      NaN
# 10019003                                      NaN
# 10020852                                      NaN
# 10023708                                      NaN
# 10031358                                      NaN
# 10035631                                      0.0
# 10046166                                      NaN
# 10047172                                      NaN
# 10051990                                      NaN
#
#           Intubation__linear_trend__attr_"intercept"  \
# 10004235                                         NaN
# 10004720                                         NaN
# 10019003                                         NaN
# 10020852                                         NaN
# 10023708                                         NaN
# 10031358                                         NaN
# 10035631                                         NaN
# 10046166                                         NaN
# 10047172                                         NaN
# 10051990                                         NaN
#
#           Intubation__linear_trend__attr_"slope"  \
# 10004235                                     NaN
# 10004720                                     NaN
# 10019003                                     NaN
# 10020852                                     NaN
# 10023708                                     NaN
# 10031358                                     NaN
# 10035631                                     NaN
# 10046166                                     NaN
# 10047172                                     NaN
# 10051990                                     NaN
#
#           Intubation__linear_trend__attr_"stderr"
# 10004235                                      NaN
# 10004720                                      NaN
# 10019003                                      NaN
# 10020852                                      NaN
# 10023708                                      NaN
# 10031358                                      NaN
# 10035631                                      NaN
# 10046166                                      NaN
# 10047172                                      NaN
# 10051990                                      NaN
#
# [10 rows x 184 columns]

# %%
demographics_fusion
# Out:
#         subject_id   hadm_id   stay_id            admittime  de_0  de_1  de_2  \
# 79344     10046166  23223084  38337371  2133-01-10 14:00:00    67     1     7
# 79345     10046166  23223084  38337371  2133-01-10 14:00:00    67     1     7
# 79346     10046166  23223084  38337371  2133-01-10 14:00:00    67     1     7
# 79347     10046166  23223084  38337371  2133-01-10 14:00:00    67     1     7
# 79348     10046166  23223084  38337371  2133-01-10 14:00:00    67     1     7
# ...            ...       ...       ...                  ...   ...   ...   ...
# 391413    10051990  24801170  33695733  2188-10-27 04:31:00    55     1     7
# 391414    10051990  24801170  33695733  2188-10-27 04:31:00    55     1     7
# 391415    10051990  24801170  33695733  2188-10-27 04:31:00    55     1     7
# 391416    10051990  24801170  33695733  2188-10-27 04:31:00    55     1     7
# 391417    10051990  24801170  33695733  2188-10-27 04:31:00    55     1     7
#
#         de_3  de_4  de_5  ...                                      dicom_id  \
# 79344      1     1     2  ...  427446c1-881f5cce-85191ce1-91a58ba9-0a57d3f5
# 79345      1     1     2  ...  abea5eb9-b7c32823-3a14c5ca-77868030-69c83139
# 79346      1     1     2  ...  3a8a17fc-3cd357d9-83466363-91dc5a06-a401e5ed
# 79347      1     1     2  ...  6130440f-929f5fae-e4b47406-634aedcb-3dd112ec
# 79348      1     1     2  ...  6fde5b65-a0efc54f-dbd690f2-5f9f941a-2b770631
# ...      ...   ...   ...  ...                                           ...
# 391413     0     1     2  ...  457bdad8-c45edc64-452fde8e-f5adda5c-f386693e
# 391414     0     1     2  ...  33d58ec3-6149bb3c-259cbce7-ca794841-9831e36d
# 391415     0     1     2  ...  c246abe6-fe4c5191-d914aaab-1eba4d2e-28970fc9
# 391416     0     1     2  ...  c3be88b4-a181c57a-713c47dc-224eed4e-ca2f9f0a
# 391417     0     1     2  ...  457bdad8-c45edc64-452fde8e-f5adda5c-f386693e
#
#         PerformedProcedureStepDescription  ViewPosition  Rows  Columns  \
# 79344                  CHEST (PA AND LAT)       LATERAL  3056     2544
# 79345                  CHEST (PA AND LAT)            AP  2544     3056
# 79346                  CHEST (PA AND LAT)            AP  2544     3056
# 79347                  CHEST (PA AND LAT)       LATERAL  3056     2544
# 79348                  CHEST (PA AND LAT)       LATERAL  3056     2544
# ...                                   ...           ...   ...      ...
# 391413                CHEST (PORTABLE AP)            AP  2539     3050
# 391414                     Performed Desc            LL  2022     1759
# 391415                     Performed Desc            LL  2022     1752
# 391416                 CHEST (PA AND LAT)            AP  2539     3050
# 391417                CHEST (PORTABLE AP)            AP  2539     3050
#
#         StudyDate   StudyTime  ProcedureCodeSequence_CodeMeaning  \
# 79344    21331006    4228.656                 CHEST (PA AND LAT)
# 79345    21331006    4228.656                 CHEST (PA AND LAT)
# 79346    21330919  193924.125                 CHEST (PA AND LAT)
# 79347    21330919  193924.125                 CHEST (PA AND LAT)
# 79348    21330919  193924.125                 CHEST (PA AND LAT)
# ...           ...         ...                                ...
# 391413   21881101  125611.359                CHEST (PORTABLE AP)
# 391414   21881029  102332.000                 CHEST (PA AND LAT)
# 391415   21881029  102332.000                 CHEST (PA AND LAT)
# 391416   21881029  102100.812                 CHEST (PA AND LAT)
# 391417   21881101  125611.359                CHEST (PORTABLE AP)
#
#         ViewCodeSequence_CodeMeaning  \
# 79344                        lateral
# 79345               antero-posterior
# 79346               antero-posterior
# 79347                        lateral
# 79348                        lateral
# ...                              ...
# 391413              antero-posterior
# 391414                  left lateral
# 391415                  left lateral
# 391416              antero-posterior
# 391417              antero-posterior
#
#         PatientOrientationCodeSequence_CodeMeaning
# 79344                                        Erect
# 79345                                        Erect
# 79346                                        Erect
# 79347                                        Erect
# 79348                                        Erect
# ...                                            ...
# 391413                                       Erect
# 391414                                   Recumbent
# 391415                                   Recumbent
# 391416                                       Erect
# 391417                                       Erect
#
# [505 rows x 36 columns]

# %% [markdown]
# ### Renaming the index as subject_id

# %% [markdown]
# Rename the genarated dataframe index for the purpose of exporting to csv:

# %%
fusion_dataframe.index.names = ["subject_id"]

# %%
fusion_dataframe.head()
# Out:
#        subject_id     hadm_id     stay_id            admittime  de_0  de_1  \
# 79344  10046166.0  23223084.0  38337371.0  2133-01-10 14:00:00  67.0   1.0
# 79345  10046166.0  23223084.0  38337371.0  2133-01-10 14:00:00  67.0   1.0
# 79346  10046166.0  23223084.0  38337371.0  2133-01-10 14:00:00  67.0   1.0
# 79347  10046166.0  23223084.0  38337371.0  2133-01-10 14:00:00  67.0   1.0
# 79348  10046166.0  23223084.0  38337371.0  2133-01-10 14:00:00  67.0   1.0
#
#        de_2  de_3  de_4  de_5  ...  \
# 79344   7.0   1.0   1.0   2.0  ...
# 79345   7.0   1.0   1.0   2.0  ...
# 79346   7.0   1.0   1.0   2.0  ...
# 79347   7.0   1.0   1.0   2.0  ...
# 79348   7.0   1.0   1.0   2.0  ...
#
#        Intubation__large_standard_deviation__r_0.8  \
# 79344                                          NaN
# 79345                                          NaN
# 79346                                          NaN
# 79347                                          NaN
# 79348                                          NaN
#
#        Intubation__quantile__q_0.25  Intubation__quantile__q_0.5  \
# 79344                           NaN                          NaN
# 79345                           NaN                          NaN
# 79346                           NaN                          NaN
# 79347                           NaN                          NaN
# 79348                           NaN                          NaN
#
#        Intubation__quantile__q_0.75  Intubation__quantile__q_1  \
# 79344                           NaN                        NaN
# 79345                           NaN                        NaN
# 79346                           NaN                        NaN
# 79347                           NaN                        NaN
# 79348                           NaN                        NaN
#
#        Intubation__linear_trend__attr_"pvalue"  \
# 79344                                      NaN
# 79345                                      NaN
# 79346                                      NaN
# 79347                                      NaN
# 79348                                      NaN
#
#        Intubation__linear_trend__attr_"rvalue"  \
# 79344                                      NaN
# 79345                                      NaN
# 79346                                      NaN
# 79347                                      NaN
# 79348                                      NaN
#
#        Intubation__linear_trend__attr_"intercept"  \
# 79344                                         NaN
# 79345                                         NaN
# 79346                                         NaN
# 79347                                         NaN
# 79348                                         NaN
#
#        Intubation__linear_trend__attr_"slope"  \
# 79344                                     NaN
# 79345                                     NaN
# 79346                                     NaN
# 79347                                     NaN
# 79348                                     NaN
#
#        Intubation__linear_trend__attr_"stderr"
# 79344                                      NaN
# 79345                                      NaN
# 79346                                      NaN
# 79347                                      NaN
# 79348                                      NaN
#
# [5 rows x 220 columns]

# %% [markdown]
# ### Exporting the dataframe to a csv file

# %%
fusion_dataframe.to_csv("csvs/fusion_dataframe.csv", index=True)

# %% [markdown]
# The goal of this notebook is to use the methods in the module ```extraction_classes.py``` and the datasources in ```csv``` to generate demographic and time series embeddings.
#
# in the first cell, we import all constants and modules necessary for this notebook, then in the following cells, we create dataframes from extracted features using the functions mentionned above.
#
# And finally, we concatenate the dataframe to create our fusion dataframe to be used in machine learning.
#
# Note: in this notebook, we only use a cohort of 10 patients to make the data processing and extraction easier for our tests. Objects from classes are intantiated  inside each extraction line. For example:
#
# ``extraction_classes.Event_extraction(patient).extract_chart_events(patient)`` in this code, the loop creates an object ``Event_extraction`` for each ``patient`` in the cohort and apllies the method  ``extract_chart_events``.
#
#
# To generate embeddings for all patients, more processing time is required, especially for time series feature extraction.

# %% [markdown]
# ### Imports

# %%
import os
os.chdir('../..')

from src.data import constants
from src.utils import extraction_classes

import pandas as pd

# %% [markdown]
# ## Create chart events features for patient cohort

# %% [markdown]
# Start by creating an empty list that will be filled with the extracted features for chart events:

# %%
chart_fusion = []
for patient in constants.cohort:

    chart_fusion.append(extraction_classes.Event_extraction(patient).extract_chart_events(patient))
# Out:
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 319.83it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 221.42it/s]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 260.34it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 245.57it/s]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 239.02it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 227.94it/s]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 252.29it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 408.76it/s]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 306.15it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 237.93it/s]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 244.75it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 283.19it/s]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 260.11it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 256.39it/s]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 224.80it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 495.55it/s]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 256.91it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 245.58it/s]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chartevents_subject_id_example_events[i][constants.chart_event_list[i]] = df_chartevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 214.95it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 275.38it/s]

# %% [markdown]
# ### Concatenate chart events fusion features

# %% [markdown]
# Concatenate features along the 0 axis for all patients:

# %%
chart_fusion = pd.concat(chart_fusion, axis=0)

# %% [markdown]
# ## Create lab events features for patient cohort

# %% [markdown]
# Start by creating an empty list that will be filled with the extracted features for lab events:

# %%
lab_fusion = []
for patient in constants.cohort:
    
    lab_fusion.append(extraction_classes.Event_extraction(patient).extract_lab_events(patient))
# Out:
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 336.51it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 313.34it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 299.85it/s]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 284.86it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 267.94it/s]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 275.36it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 275.04it/s]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 274.55it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 376.34it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 287.91it/s]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 309.22it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 337.79it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 286.69it/s]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 314.23it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 339.51it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 289.44it/s]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 227.80it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 423.54it/s]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 348.36it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 290.46it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 223.22it/s]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 320.00it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 350.23it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 259.77it/s]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labevents_subject_id_example_events[i][constants.lab_event_list[i]] = df_labevents_subject_id_example_events[i]["valuenum"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 463.56it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 325.37it/s]

# %% [markdown]
# ### Concatenate lab events fusion features

# %% [markdown]
# Concatenate features along the 0 axis for all patients:

# %%
lab_fusion = pd.concat(lab_fusion, axis=0)

# %% [markdown]
# ## Create procedure events features for patient cohort

# %% [markdown]
# Start by creating an empty list that will be filled with the extracted features for procedure events:

# %%
procedure_fusion = []
for patient in constants.cohort:
   
    procedure_fusion.append(extraction_classes.Event_extraction(patient).extract_procedure_events(patient))
# Out:
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_procedureevents_subject_id_example_events[i][constants.procedure_event_list[i]] = df_procedureevents_subject_id_example_events[i]["value"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 413.72it/s]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_procedureevents_subject_id_example_events[i][constants.procedure_event_list[i]] = df_procedureevents_subject_id_example_events[i]["value"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 291.23it/s]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_procedureevents_subject_id_example_events[i][constants.procedure_event_list[i]] = df_procedureevents_subject_id_example_events[i]["value"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_procedureevents_subject_id_example_events[i][constants.procedure_event_list[i]] = df_procedureevents_subject_id_example_events[i]["value"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 313.55it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 219.53it/s]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_procedureevents_subject_id_example_events[i][constants.procedure_event_list[i]] = df_procedureevents_subject_id_example_events[i]["value"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_procedureevents_subject_id_example_events[i][constants.procedure_event_list[i]] = df_procedureevents_subject_id_example_events[i]["value"]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_procedureevents_subject_id_example_events[i][constants.procedure_event_list[i]] = df_procedureevents_subject_id_example_events[i]["value"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 394.94it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 269.14it/s]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 271.11it/s]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_procedureevents_subject_id_example_events[i][constants.procedure_event_list[i]] = df_procedureevents_subject_id_example_events[i]["value"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 271.27it/s]
# /home/local/USHERBROOKE/fakb2301/Bureau/Brahim/mimic-iv-cxr-embeddings-main/src/utils/extraction_classes.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_procedureevents_subject_id_example_events[i][constants.procedure_event_list[i]] = df_procedureevents_subject_id_example_events[i]["value"]
# Feature Extraction: 100%|████████████████████████| 1/1 [00:00<00:00, 264.08it/s]

# %% [markdown]
# ### Concatenate procedure events fusion features

# %% [markdown]
# Concatenate features along the 0 axis for all patients:

# %%
procedure_fusion = pd.concat(procedure_fusion, axis=0)

# %% [markdown]
# ## Create demographic features for patient cohort

# %% [markdown]
# Create and object `Demographic_extraction` and call medthod `extract_demographics` :

# %%
demographics_fusion = extraction_classes.Demographic_extraction().extract_demographics()

# %% [markdown]
# Filter dataframe using patients in the `cohort`:

# %%
demographics_fusion = demographics_fusion[demographics_fusion['subject_id'].isin(constants.cohort)]

# %%
demographics_fusion
# Out:
#         subject_id  de_0  de_1  de_2  de_3  de_4  de_5  death_status
# 79344     10046166    67     1     7     1     1     2             0
# 103043    10047172    73     1     7     1     1     2             1
# 160461    10035631    63     1     7     1     1     2             1
# 276783    10023708    82     0     7     3     1     1             0
# 310934    10004720    61     1     7     2     1     1             1
# 335724    10031358    58     1     7     1     1     1             0
# 340792    10020852    24     0     7     2     1     0             0
# 345222    10019003    65     0     7     3     1     2             0
# 346787    10004235    47     1     2     2     1     0             0
# 391398    10051990    55     1     7     0     1     2             0

# %%
#df.drop_duplicates(subset=['brand'])

demographics_fusion = demographics_fusion.drop_duplicates(subset=['subject_id'])

# %%
demographics_fusion
# Out:
#         subject_id  de_0  de_1  de_2  de_3  de_4  de_5  death_status
# 79344     10046166    67     1     7     1     1     2             0
# 103043    10047172    73     1     7     1     1     2             1
# 160461    10035631    63     1     7     1     1     2             1
# 276783    10023708    82     0     7     3     1     1             0
# 310934    10004720    61     1     7     2     1     1             1
# 335724    10031358    58     1     7     1     1     1             0
# 340792    10020852    24     0     7     2     1     0             0
# 345222    10019003    65     0     7     3     1     2             0
# 346787    10004235    47     1     2     2     1     0             0
# 391398    10051990    55     1     7     0     1     2             0

# %%
demographics_fusion = demographics_fusion.set_index('subject_id')

# %%
demographics_fusion
# Out:
#             de_0  de_1  de_2  de_3  de_4  de_5  death_status
# subject_id
# 10046166      67     1     7     1     1     2             0
# 10047172      73     1     7     1     1     2             1
# 10035631      63     1     7     1     1     2             1
# 10023708      82     0     7     3     1     1             0
# 10004720      61     1     7     2     1     1             1
# 10031358      58     1     7     1     1     1             0
# 10020852      24     0     7     2     1     0             0
# 10019003      65     0     7     3     1     2             0
# 10004235      47     1     2     2     1     0             0
# 10051990      55     1     7     0     1     2             0

# %% [markdown]
# # Concatenate fusion features horizontally for all patients

# %% [markdown]
# Concatenate the generated dataframes to combine  all features

# %%
fusion_ts_dem_dataframe = pd.concat([demographics_fusion, chart_fusion, lab_fusion, procedure_fusion ], axis=1)

# %%
fusion_ts_dem_dataframe
# Out:
#           de_0  de_1  de_2  de_3  de_4  de_5  death_status  \
# 10046166    67     1     7     1     1     2             0
# 10047172    73     1     7     1     1     2             1
# 10035631    63     1     7     1     1     2             1
# 10023708    82     0     7     3     1     1             0
# 10004720    61     1     7     2     1     1             1
# 10031358    58     1     7     1     1     1             0
# 10020852    24     0     7     2     1     0             0
# 10019003    65     0     7     3     1     2             0
# 10004235    47     1     2     2     1     0             0
# 10051990    55     1     7     0     1     2             0
#
#           Heart Rate__length  Heart Rate__absolute_sum_of_changes  \
# 10046166                23.0                                100.0
# 10047172                45.0                                193.0
# 10035631               364.0                               1268.0
# 10023708                59.0                                268.0
# 10004720               142.0                                836.0
# 10031358                20.0                                103.0
# 10020852                43.0                                235.0
# 10019003               267.0                                759.0
# 10004235               121.0                                694.0
# 10051990                52.0                                132.0
#
#           Heart Rate__maximum  ...  \
# 10046166                 71.0  ...
# 10047172                 93.0  ...
# 10035631                174.0  ...
# 10023708                 88.0  ...
# 10004720                122.0  ...
# 10031358                 91.0  ...
# 10020852                 93.0  ...
# 10019003                128.0  ...
# 10004235                144.0  ...
# 10051990                100.0  ...
#
#           Intubation__large_standard_deviation__r_0.8  \
# 10046166                                          NaN
# 10047172                                          NaN
# 10035631                                          0.0
# 10023708                                          NaN
# 10004720                                          NaN
# 10031358                                          NaN
# 10020852                                          NaN
# 10019003                                          NaN
# 10004235                                          NaN
# 10051990                                          NaN
#
#           Intubation__quantile__q_0.25  Intubation__quantile__q_0.5  \
# 10046166                           NaN                          NaN
# 10047172                           NaN                          NaN
# 10035631                           1.0                          1.0
# 10023708                           NaN                          NaN
# 10004720                           NaN                          NaN
# 10031358                           NaN                          NaN
# 10020852                           NaN                          NaN
# 10019003                           NaN                          NaN
# 10004235                           NaN                          NaN
# 10051990                           NaN                          NaN
#
#           Intubation__quantile__q_0.75  Intubation__quantile__q_1  \
# 10046166                           NaN                        NaN
# 10047172                           NaN                        NaN
# 10035631                           1.0                        1.0
# 10023708                           NaN                        NaN
# 10004720                           NaN                        NaN
# 10031358                           NaN                        NaN
# 10020852                           NaN                        NaN
# 10019003                           NaN                        NaN
# 10004235                           NaN                        NaN
# 10051990                           NaN                        NaN
#
#           Intubation__linear_trend__attr_"pvalue"  \
# 10046166                                      NaN
# 10047172                                      NaN
# 10035631                                      NaN
# 10023708                                      NaN
# 10004720                                      NaN
# 10031358                                      NaN
# 10020852                                      NaN
# 10019003                                      NaN
# 10004235                                      NaN
# 10051990                                      NaN
#
#           Intubation__linear_trend__attr_"rvalue"  \
# 10046166                                      NaN
# 10047172                                      NaN
# 10035631                                      0.0
# 10023708                                      NaN
# 10004720                                      NaN
# 10031358                                      NaN
# 10020852                                      NaN
# 10019003                                      NaN
# 10004235                                      NaN
# 10051990                                      NaN
#
#           Intubation__linear_trend__attr_"intercept"  \
# 10046166                                         NaN
# 10047172                                         NaN
# 10035631                                         NaN
# 10023708                                         NaN
# 10004720                                         NaN
# 10031358                                         NaN
# 10020852                                         NaN
# 10019003                                         NaN
# 10004235                                         NaN
# 10051990                                         NaN
#
#           Intubation__linear_trend__attr_"slope"  \
# 10046166                                     NaN
# 10047172                                     NaN
# 10035631                                     NaN
# 10023708                                     NaN
# 10004720                                     NaN
# 10031358                                     NaN
# 10020852                                     NaN
# 10019003                                     NaN
# 10004235                                     NaN
# 10051990                                     NaN
#
#           Intubation__linear_trend__attr_"stderr"
# 10046166                                      NaN
# 10047172                                      NaN
# 10035631                                      NaN
# 10023708                                      NaN
# 10004720                                      NaN
# 10031358                                      NaN
# 10020852                                      NaN
# 10019003                                      NaN
# 10004235                                      NaN
# 10051990                                      NaN
#
# [10 rows x 191 columns]

# %% [markdown]
# ### Renaming the index as subject_id

# %% [markdown]
# Rename the genarated dataframe index for the purpose of exporting to csv (order by subject_id):

# %%
fusion_ts_dem_dataframe.index.names = ["subject_id"]
fusion_ts_dem_dataframe = fusion_ts_dem_dataframe.sort_values(by=['subject_id'])

# %%
fusion_ts_dem_dataframe
# Out:
#             de_0  de_1  de_2  de_3  de_4  de_5  death_status  \
# subject_id
# 10004235      47     1     2     2     1     0             0
# 10004720      61     1     7     2     1     1             1
# 10019003      65     0     7     3     1     2             0
# 10020852      24     0     7     2     1     0             0
# 10023708      82     0     7     3     1     1             0
# 10031358      58     1     7     1     1     1             0
# 10035631      63     1     7     1     1     2             1
# 10046166      67     1     7     1     1     2             0
# 10047172      73     1     7     1     1     2             1
# 10051990      55     1     7     0     1     2             0
#
#             Heart Rate__length  Heart Rate__absolute_sum_of_changes  \
# subject_id
# 10004235                 121.0                                694.0
# 10004720                 142.0                                836.0
# 10019003                 267.0                                759.0
# 10020852                  43.0                                235.0
# 10023708                  59.0                                268.0
# 10031358                  20.0                                103.0
# 10035631                 364.0                               1268.0
# 10046166                  23.0                                100.0
# 10047172                  45.0                                193.0
# 10051990                  52.0                                132.0
#
#             Heart Rate__maximum  ...  \
# subject_id                       ...
# 10004235                  144.0  ...
# 10004720                  122.0  ...
# 10019003                  128.0  ...
# 10020852                   93.0  ...
# 10023708                   88.0  ...
# 10031358                   91.0  ...
# 10035631                  174.0  ...
# 10046166                   71.0  ...
# 10047172                   93.0  ...
# 10051990                  100.0  ...
#
#             Intubation__large_standard_deviation__r_0.8  \
# subject_id
# 10004235                                            NaN
# 10004720                                            NaN
# 10019003                                            NaN
# 10020852                                            NaN
# 10023708                                            NaN
# 10031358                                            NaN
# 10035631                                            0.0
# 10046166                                            NaN
# 10047172                                            NaN
# 10051990                                            NaN
#
#             Intubation__quantile__q_0.25  Intubation__quantile__q_0.5  \
# subject_id
# 10004235                             NaN                          NaN
# 10004720                             NaN                          NaN
# 10019003                             NaN                          NaN
# 10020852                             NaN                          NaN
# 10023708                             NaN                          NaN
# 10031358                             NaN                          NaN
# 10035631                             1.0                          1.0
# 10046166                             NaN                          NaN
# 10047172                             NaN                          NaN
# 10051990                             NaN                          NaN
#
#             Intubation__quantile__q_0.75  Intubation__quantile__q_1  \
# subject_id
# 10004235                             NaN                        NaN
# 10004720                             NaN                        NaN
# 10019003                             NaN                        NaN
# 10020852                             NaN                        NaN
# 10023708                             NaN                        NaN
# 10031358                             NaN                        NaN
# 10035631                             1.0                        1.0
# 10046166                             NaN                        NaN
# 10047172                             NaN                        NaN
# 10051990                             NaN                        NaN
#
#             Intubation__linear_trend__attr_"pvalue"  \
# subject_id
# 10004235                                        NaN
# 10004720                                        NaN
# 10019003                                        NaN
# 10020852                                        NaN
# 10023708                                        NaN
# 10031358                                        NaN
# 10035631                                        NaN
# 10046166                                        NaN
# 10047172                                        NaN
# 10051990                                        NaN
#
#             Intubation__linear_trend__attr_"rvalue"  \
# subject_id
# 10004235                                        NaN
# 10004720                                        NaN
# 10019003                                        NaN
# 10020852                                        NaN
# 10023708                                        NaN
# 10031358                                        NaN
# 10035631                                        0.0
# 10046166                                        NaN
# 10047172                                        NaN
# 10051990                                        NaN
#
#             Intubation__linear_trend__attr_"intercept"  \
# subject_id
# 10004235                                           NaN
# 10004720                                           NaN
# 10019003                                           NaN
# 10020852                                           NaN
# 10023708                                           NaN
# 10031358                                           NaN
# 10035631                                           NaN
# 10046166                                           NaN
# 10047172                                           NaN
# 10051990                                           NaN
#
#             Intubation__linear_trend__attr_"slope"  \
# subject_id
# 10004235                                       NaN
# 10004720                                       NaN
# 10019003                                       NaN
# 10020852                                       NaN
# 10023708                                       NaN
# 10031358                                       NaN
# 10035631                                       NaN
# 10046166                                       NaN
# 10047172                                       NaN
# 10051990                                       NaN
#
#             Intubation__linear_trend__attr_"stderr"
# subject_id
# 10004235                                        NaN
# 10004720                                        NaN
# 10019003                                        NaN
# 10020852                                        NaN
# 10023708                                        NaN
# 10031358                                        NaN
# 10035631                                        NaN
# 10046166                                        NaN
# 10047172                                        NaN
# 10051990                                        NaN
#
# [10 rows x 191 columns]

# %% [markdown]
# ### Exporting the dataframe to a csv file

# %%
fusion_dataframe.to_csv("csvs/fusion_ts_dem_dataframe.csv", index=True)

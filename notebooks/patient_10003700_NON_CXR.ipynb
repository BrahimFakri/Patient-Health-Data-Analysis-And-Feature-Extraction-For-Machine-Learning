# %% [markdown]
# ### Imports

# %%
import os
os.chdir('../')

from src.data import constants
import pandas as pd
from pandas import read_csv
import datetime as dt
import numpy as np

# %% [markdown]
# ### Read all data from local source

# %% [markdown]
# MIMIC-IV Dataset

# %%
## CORE
df_admissions = pd.read_csv(constants.admissions, dtype={'admission_location': 'object','deathtime': 'object','edouttime': 'object','edregtime': 'object'})
df_patients = pd.read_csv(constants.patients, dtype={'dod': 'object'})  
df_transfers = pd.read_csv(constants.transfers, dtype={'careunit': 'object'})

# %%
## ICU
df_d_items = pd.read_csv(constants.d_items)

df_chartevents = pd.read_csv(constants.chartevents, low_memory=False, dtype={'value': 'object', 'valueuom': 'object'}, nrows=2000)

# %% [markdown]
# ### Create dataframe for patient  10003700

# %% [markdown]
# Core

# %%
df_admissions = df_admissions[df_admissions["subject_id"]==10003700]
df_patients = df_patients[df_patients["subject_id"]==10003700]
df_transfers = df_transfers[df_transfers["subject_id"]==10003700]

# %% [markdown]
# ICU

# %%
df_chartevents = df_chartevents[df_chartevents["subject_id"]==10003700]

# %%
### Fix data type issues to allow for merging


df_admissions['admittime'] = pd.to_datetime(df_admissions['admittime'])
df_admissions['dischtime'] = pd.to_datetime(df_admissions['dischtime'])
df_admissions['deathtime'] = pd.to_datetime(df_admissions['deathtime'])
df_admissions['edregtime'] = pd.to_datetime(df_admissions['edregtime'])
df_admissions['edouttime'] = pd.to_datetime(df_admissions['edouttime'])

df_transfers['intime'] = pd.to_datetime(df_transfers['intime'])
df_transfers['outtime'] = pd.to_datetime(df_transfers['outtime'])

df_chartevents['charttime'] = pd.to_datetime(df_chartevents['charttime'])
df_chartevents['storetime'] = pd.to_datetime(df_chartevents['storetime'])

# %%
df_admissions.dtypes, df_transfers.dtypes, df_chartevents.dtypes
# Out:
# (subject_id                       int64
#  hadm_id                          int64
#  admittime               datetime64[ns]
#  dischtime               datetime64[ns]
#  deathtime               datetime64[ns]
#  admission_type                  object
#  admission_location              object
#  discharge_location              object
#  insurance                       object
#  language                        object
#  marital_status                  object
#  ethnicity                       object
#  edregtime               datetime64[ns]
#  edouttime               datetime64[ns]
#  hospital_expire_flag             int64
#  dtype: object,
#  subject_id              int64
#  hadm_id               float64
#  transfer_id             int64
#  eventtype              object
#  careunit               object
#  intime         datetime64[ns]
#  outtime        datetime64[ns]
#  dtype: object,
#  subject_id             int64
#  hadm_id                int64
#  stay_id                int64
#  charttime     datetime64[ns]
#  storetime     datetime64[ns]
#  itemid                 int64
#  value                 object
#  valuenum             float64
#  valueuom              object
#  warning                int64
#  dtype: object)

# %%
df_chartevents
# Out:
#      subject_id   hadm_id   stay_id           charttime           storetime  \
# 0      10003700  28623837  30600691 2165-04-24 05:10:00 2165-04-24 05:11:00
# 1      10003700  28623837  30600691 2165-04-24 05:12:00 2165-04-24 05:14:00
# 2      10003700  28623837  30600691 2165-04-24 05:12:00 2165-04-24 05:14:00
# 3      10003700  28623837  30600691 2165-04-24 05:12:00 2165-04-24 05:14:00
# 4      10003700  28623837  30600691 2165-04-24 05:12:00 2165-04-24 05:14:00
# ..          ...       ...       ...                 ...                 ...
# 131    10003700  28623837  30600691 2165-04-24 08:00:00 2165-04-24 08:25:00
# 132    10003700  28623837  30600691 2165-04-24 08:00:00 2165-04-24 08:26:00
# 133    10003700  28623837  30600691 2165-04-24 08:00:00 2165-04-24 08:25:00
# 134    10003700  28623837  30600691 2165-04-24 08:00:00 2165-04-24 08:26:00
# 135    10003700  28623837  30600691 2165-04-24 08:00:00 2165-04-24 08:26:00
#
#      itemid value  valuenum valueuom  warning
# 0    228236     0       0.0      NaN        0
# 1    225067     0       0.0      NaN        0
# 2    225070     1       1.0      NaN        0
# 3    225076     1       1.0      NaN        0
# 4    225078     1       1.0      NaN        0
# ..      ...   ...       ...      ...      ...
# 131  225187     1       1.0      NaN        0
# 132  226137     0       0.0      NaN        0
# 133  226169     1       1.0      NaN        0
# 134  227367     1       1.0      NaN        0
# 135  228099     0       0.0      NaN        0
#
# [136 rows x 10 columns]

# %%
len(df_chartevents["itemid"].unique())

# %%
df_d_items[df_d_items["itemid"].isin([225187,225078,225117])]
# Out:
#       itemid                                   label  \
# 800   225078                     Social work consult
# 819   225117  Unable to assess nutrition / education
# 3527  225187                               Back Care
#
#                                 abbreviation      linksto          category  \
# 800                      Social work consult  chartevents  Adm History/FHPA
# 819   Unable to assess nutrition / education  chartevents  Adm History/FHPA
# 3527                               Back Care  chartevents        Treatments
#
#      unitname param_type  lownormalvalue  highnormalvalue
# 800       NaN   Checkbox             NaN              NaN
# 819       NaN   Checkbox             NaN              NaN
# 3527      NaN   Checkbox             NaN              NaN

# %%
type(df_d_items[df_d_items["itemid"]==225187]["itemid"])
# Out:
# pandas.core.series.Series

# %%
event_list = ['Social work consult','Unable to assess nutrition / education','Back Care'] 

df_d_items_chart = df_d_items[df_d_items['label'].isin(event_list)]

df_d_items_chart = df_d_items_chart[["category","label","itemid"]]

df_d_items_chart
# Out:
#               category                                   label  itemid
# 800   Adm History/FHPA                     Social work consult  225078
# 819   Adm History/FHPA  Unable to assess nutrition / education  225117
# 3527        Treatments                               Back Care  225187

# %%
df_chartevents = df_chartevents[df_chartevents["itemid"].isin([225187,225078,225117])]

# %%
df_chartevents
# Out:
#      subject_id   hadm_id   stay_id           charttime           storetime  \
# 4      10003700  28623837  30600691 2165-04-24 05:12:00 2165-04-24 05:14:00
# 10     10003700  28623837  30600691 2165-04-24 05:12:00 2165-04-24 05:14:00
# 33     10003700  28623837  30600691 2165-04-24 05:42:00 2165-04-24 05:42:00
# 67     10003700  28623837  30600691 2165-04-24 06:02:00 2165-04-24 06:02:00
# 131    10003700  28623837  30600691 2165-04-24 08:00:00 2165-04-24 08:25:00
#
#      itemid value  valuenum valueuom  warning
# 4    225078     1       1.0      NaN        0
# 10   225117     1       1.0      NaN        0
# 33   225187     1       1.0      NaN        0
# 67   225187     1       1.0      NaN        0
# 131  225187     1       1.0      NaN        0

# %%
df_chartevents["valueuom"].fillna('', inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
df_chartevents
# Out:
#      subject_id   hadm_id   stay_id           charttime           storetime  \
# 4      10003700  28623837  30600691 2165-04-24 05:12:00 2165-04-24 05:14:00
# 10     10003700  28623837  30600691 2165-04-24 05:12:00 2165-04-24 05:14:00
# 33     10003700  28623837  30600691 2165-04-24 05:42:00 2165-04-24 05:42:00
# 67     10003700  28623837  30600691 2165-04-24 06:02:00 2165-04-24 06:02:00
# 131    10003700  28623837  30600691 2165-04-24 08:00:00 2165-04-24 08:25:00
#
#      itemid value  valuenum valueuom  warning
# 4    225078     1       1.0                 0
# 10   225117     1       1.0                 0
# 33   225187     1       1.0                 0
# 67   225187     1       1.0                 0
# 131  225187     1       1.0                 0

# %%
df_chartevents_d_items_chart = df_chartevents.merge(df_d_items_chart, on=("itemid"))

# %%
df_chartevents_d_items_chart
# Out:
#    subject_id   hadm_id   stay_id           charttime           storetime  \
# 0    10003700  28623837  30600691 2165-04-24 05:12:00 2165-04-24 05:14:00
# 1    10003700  28623837  30600691 2165-04-24 05:12:00 2165-04-24 05:14:00
# 2    10003700  28623837  30600691 2165-04-24 05:42:00 2165-04-24 05:42:00
# 3    10003700  28623837  30600691 2165-04-24 06:02:00 2165-04-24 06:02:00
# 4    10003700  28623837  30600691 2165-04-24 08:00:00 2165-04-24 08:25:00
#
#    itemid value  valuenum valueuom  warning          category  \
# 0  225078     1       1.0                 0  Adm History/FHPA
# 1  225117     1       1.0                 0  Adm History/FHPA
# 2  225187     1       1.0                 0        Treatments
# 3  225187     1       1.0                 0        Treatments
# 4  225187     1       1.0                 0        Treatments
#
#                                     label
# 0                     Social work consult
# 1  Unable to assess nutrition / education
# 2                               Back Care
# 3                               Back Care
# 4                               Back Care

# %%
# create a new table with additional columns with label list  
df1 = df_chartevents[['subject_id', 'hadm_id', 'stay_id', 'charttime']] 
for event in event_list:    
    df1[event] = 0
# Out:
# C:\Users\B\AppData\Local\Temp/ipykernel_1096/1050507014.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[event] = 0

# %%
df1
# Out:
#      subject_id   hadm_id   stay_id           charttime  Social work consult  \
# 4      10003700  28623837  30600691 2165-04-24 05:12:00                    1
# 10     10003700  28623837  30600691 2165-04-24 05:12:00                    0
# 33     10003700  28623837  30600691 2165-04-24 05:42:00                    0
# 67     10003700  28623837  30600691 2165-04-24 06:02:00                    0
# 131    10003700  28623837  30600691 2165-04-24 08:00:00                    0
#
#      Unable to assess nutrition / education  Back Care
# 4                                         0          0
# 10                                        1          0
# 33                                        0          1
# 67                                        0          1
# 131                                       0          1

# %%
for i in df_chartevents_d_items_chart["label"].index:
    print (df_chartevents_d_items_chart["label"][i],df_chartevents_d_items_chart["valuenum"][i])
    df1
# Out:
# Social work consult 1.0
# Unable to assess nutrition / education 1.0
# Back Care 1.0
# Back Care 1.0
# Back Care 1.0

# %%
df_chartevents_d_items_chart["valuenum"][0]
# Out:
# 1.0

# %%
# Out:
# 0

# %%
df1[event_list[0]][df1.index[0]] = df_chartevents_d_items_chart["valuenum"][0]

df1[event_list[1]][df1.index[1]] = df_chartevents_d_items_chart["valuenum"][1]

df1[event_list[2]][df1.index[2]] = df_chartevents_d_items_chart["valuenum"][2]
df1[event_list[2]][df1.index[3]] = df_chartevents_d_items_chart["valuenum"][3]
df1[event_list[2]][df1.index[4]] = df_chartevents_d_items_chart["valuenum"][4]
# Out:
# C:\Users\B\AppData\Local\Temp/ipykernel_1096/2553213796.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[event_list[0]][df1.index[0]] = df_chartevents_d_items_chart["valuenum"][0]
# C:\Users\B\AppData\Local\Temp/ipykernel_1096/2553213796.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[event_list[1]][df1.index[1]] = df_chartevents_d_items_chart["valuenum"][1]
# C:\Users\B\AppData\Local\Temp/ipykernel_1096/2553213796.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[event_list[2]][df1.index[2]] = df_chartevents_d_items_chart["valuenum"][2]
# C:\Users\B\AppData\Local\Temp/ipykernel_1096/2553213796.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[event_list[2]][df1.index[3]] = df_chartevents_d_items_chart["valuenum"][3]
# C:\Users\B\AppData\Local\Temp/ipykernel_1096/2553213796.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[event_list[2]][df1.index[4]] = df_chartevents_d_items_chart["valuenum"][4]

# %%
df1
# Out:
#      subject_id   hadm_id   stay_id           charttime  Social work consult  \
# 4      10003700  28623837  30600691 2165-04-24 05:12:00                    1
# 10     10003700  28623837  30600691 2165-04-24 05:12:00                    0
# 33     10003700  28623837  30600691 2165-04-24 05:42:00                    0
# 67     10003700  28623837  30600691 2165-04-24 06:02:00                    0
# 131    10003700  28623837  30600691 2165-04-24 08:00:00                    0
#
#      Unable to assess nutrition / education  Back Care
# 4                                         0          0
# 10                                        1          0
# 33                                        0          1
# 67                                        0          1
# 131                                       0          1

# %%
df1[["stay_id","charttime","Social work consult","Unable to assess nutrition / education","Back Care"]]
# Out:
#            stay_id           charttime  Social work consult  \
# df1index
# 4         30600691 2165-04-24 05:12:00                    1
# 10        30600691 2165-04-24 05:12:00                    0
# 33        30600691 2165-04-24 05:42:00                    0
# 67        30600691 2165-04-24 06:02:00                    0
# 131       30600691 2165-04-24 08:00:00                    0
#
#           Unable to assess nutrition / education  Back Care
# df1index
# 4                                              0          0
# 10                                             1          0
# 33                                             0          1
# 67                                             0          1
# 131                                            0          1

# %%
fc_parameters = {"length": None,
                    "absolute_sum_of_changes": None, 
                    "maximum": None, 
                    "mean": None,
                    "mean_abs_change": None,
                    "mean_change": None,
                    "median": None,
                    "minimum": None,
                    "standard_deviation": None,
                    "variance": None,
                    "large_standard_deviation": [{"r": r * 0.2} for r in range(1, 5)],
                    "quantile": [{"q": q} for q in [.25, .5, .75, 1]],
                    "linear_trend": [{"attr": "pvalue"}, {"attr": "rvalue"}, {"attr": "intercept"},{"attr": "slope"}, {"attr": "stderr"}]}

# %%
from tsfresh import extract_features

extracted_features = extract_features(df1[["stay_id","charttime","Social work consult","Unable to assess nutrition / education","Back Care"]], column_id="stay_id", column_sort="charttime", default_fc_parameters=fc_parameters)
# Out:
# Feature Extraction: 100%|███████████████████████████████████████████████████████████████████████| 3/3 [00:02<00:00,  1.47it/s]

# %%
extracted_features.columns
# Out:
# Index(['Social work consult__length',
#        'Social work consult__absolute_sum_of_changes',
#        'Social work consult__maximum', 'Social work consult__mean',
#        'Social work consult__mean_abs_change',
#        'Social work consult__mean_change', 'Social work consult__median',
#        'Social work consult__minimum',
#        'Social work consult__standard_deviation',
#        'Social work consult__variance',
#        'Social work consult__large_standard_deviation__r_0.2',
#        'Social work consult__large_standard_deviation__r_0.4',
#        'Social work consult__large_standard_deviation__r_0.6000000000000001',
#        'Social work consult__large_standard_deviation__r_0.8',
#        'Social work consult__quantile__q_0.25',
#        'Social work consult__quantile__q_0.5',
#        'Social work consult__quantile__q_0.75',
#        'Social work consult__quantile__q_1',
#        'Social work consult__linear_trend__attr_"pvalue"',
#        'Social work consult__linear_trend__attr_"rvalue"',
#        'Social work consult__linear_trend__attr_"intercept"',
#        'Social work consult__linear_trend__attr_"slope"',
#        'Social work consult__linear_trend__attr_"stderr"',
#        'Unable to assess nutrition / education__length',
#        'Unable to assess nutrition / education__absolute_sum_of_changes',
#        'Unable to assess nutrition / education__maximum',
#        'Unable to assess nutrition / education__mean',
#        'Unable to assess nutrition / education__mean_abs_change',
#        'Unable to assess nutrition / education__mean_change',
#        'Unable to assess nutrition / education__median',
#        'Unable to assess nutrition / education__minimum',
#        'Unable to assess nutrition / education__standard_deviation',
#        'Unable to assess nutrition / education__variance',
#        'Unable to assess nutrition / education__large_standard_deviation__r_0.2',
#        'Unable to assess nutrition / education__large_standard_deviation__r_0.4',
#        'Unable to assess nutrition / education__large_standard_deviation__r_0.6000000000000001',
#        'Unable to assess nutrition / education__large_standard_deviation__r_0.8',
#        'Unable to assess nutrition / education__quantile__q_0.25',
#        'Unable to assess nutrition / education__quantile__q_0.5',
#        'Unable to assess nutrition / education__quantile__q_0.75',
#        'Unable to assess nutrition / education__quantile__q_1',
#        'Unable to assess nutrition / education__linear_trend__attr_"pvalue"',
#        'Unable to assess nutrition / education__linear_trend__attr_"rvalue"',
#        'Unable to assess nutrition / education__linear_trend__attr_"intercept"',
#        'Unable to assess nutrition / education__linear_trend__attr_"slope"',
#        'Unable to assess nutrition / education__linear_trend__attr_"stderr"',
#        'Back Care__length', 'Back Care__absolute_sum_of_changes',
#        'Back Care__maximum', 'Back Care__mean', 'Back Care__mean_abs_change',
#        'Back Care__mean_change', 'Back Care__median', 'Back Care__minimum',
#        'Back Care__standard_deviation', 'Back Care__variance',
#        'Back Care__large_standard_deviation__r_0.2',
#        'Back Care__large_standard_deviation__r_0.4',
#        'Back Care__large_standard_deviation__r_0.6000000000000001',
#        'Back Care__large_standard_deviation__r_0.8',
#        'Back Care__quantile__q_0.25', 'Back Care__quantile__q_0.5',
#        'Back Care__quantile__q_0.75', 'Back Care__quantile__q_1',
#        'Back Care__linear_trend__attr_"pvalue"',
#        'Back Care__linear_trend__attr_"rvalue"',
#        'Back Care__linear_trend__attr_"intercept"',
#        'Back Care__linear_trend__attr_"slope"',
#        'Back Care__linear_trend__attr_"stderr"'],
#       dtype='object')

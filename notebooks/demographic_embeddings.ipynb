# %% [markdown]
# ### Imports

# %%
import os
os.chdir('../')

from src.data import constants
import pandas as pd
from pandas import read_csv
import datetime as dt
import numpy as np

from sklearn.preprocessing import LabelEncoder 
le = LabelEncoder()

# %% [markdown]
# ### Read data from local source

# %% [markdown]
# MIMIC-IV Dataset

# %% [markdown]
# Core

# %%
df_admissions = read_csv(constants.admissions)
df_patients = read_csv(constants.patients)
df_transfers = read_csv(constants.transfers)

# %% [markdown]
# ICU

# %%
df_icustays = read_csv(constants.icustays)

# %% [markdown]
# MIMIC-CXR

# %%
df_mimic_cxr_chexpert = read_csv(constants.mimic_cxr_chexpert)
df_mimic_cxr_metadata = read_csv(constants.mimic_cxr_metadata)

# %% [markdown]
# #### CORE dataset fusion

# %%
df_core_fusion = df_admissions.merge(df_patients, on=("subject_id")).merge(df_transfers, on=('subject_id', 'hadm_id'))

# %%
df_core_fusion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1840955 entries, 0 to 1840954
# Data columns (total 25 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   subject_id            int64
#  1   hadm_id               int64
#  2   admittime             object
#  3   dischtime             object
#  4   deathtime             object
#  5   admission_type        object
#  6   admission_location    object
#  7   discharge_location    object
#  8   insurance             object
#  9   language              object
#  10  marital_status        object
#  11  ethnicity             object
#  12  edregtime             object
#  13  edouttime             object
#  14  hospital_expire_flag  int64
#  15  gender                object
#  16  anchor_age            int64
#  17  anchor_year           int64
#  18  anchor_year_group     object
#  19  dod                   object
#  20  transfer_id           int64
#  21  eventtype             object
#  22  careunit              object
#  23  intime                object
#  24  outtime               object
# dtypes: int64(6), object(19)
# memory usage: 365.2+ MB

# %%
df_core_icu_fusion = df_core_fusion.merge(df_icustays, on=('subject_id', 'hadm_id'))

# %%
df_core_icu_fusion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 420372 entries, 0 to 420371
# Data columns (total 31 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   subject_id            420372 non-null  int64
#  1   hadm_id               420372 non-null  int64
#  2   admittime             420372 non-null  object
#  3   dischtime             420372 non-null  object
#  4   deathtime             47063 non-null   object
#  5   admission_type        420372 non-null  object
#  6   admission_location    420372 non-null  object
#  7   discharge_location    417901 non-null  object
#  8   insurance             420372 non-null  object
#  9   language              420372 non-null  object
#  10  marital_status        393342 non-null  object
#  11  ethnicity             420372 non-null  object
#  12  edregtime             288815 non-null  object
#  13  edouttime             288815 non-null  object
#  14  hospital_expire_flag  420372 non-null  int64
#  15  gender                420372 non-null  object
#  16  anchor_age            420372 non-null  int64
#  17  anchor_year           420372 non-null  int64
#  18  anchor_year_group     420372 non-null  object
#  19  dod                   75393 non-null   object
#  20  transfer_id           420372 non-null  int64
#  21  eventtype             420372 non-null  object
#  22  careunit              331068 non-null  object
#  23  intime_x              420372 non-null  object
#  24  outtime_x             343832 non-null  object
#  25  stay_id               420372 non-null  int64
#  26  first_careunit        420372 non-null  object
#  27  last_careunit         420372 non-null  object
#  28  intime_y              420372 non-null  object
#  29  outtime_y             420372 non-null  object
#  30  los                   420372 non-null  float64
# dtypes: float64(1), int64(7), object(23)
# memory usage: 102.6+ MB

# %% [markdown]
# #### CXR dataset fusion

# %%
df_cxr_merged = df_mimic_cxr_chexpert.merge(df_mimic_cxr_metadata, on= ('subject_id', 'study_id'))

# %%
df_cxr_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 377095 entries, 0 to 377094
# Data columns (total 26 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   subject_id                                  377095 non-null  int64
#  1   study_id                                    377095 non-null  int64
#  2   Atelectasis                                 82830 non-null   float64
#  3   Cardiomegaly                                97781 non-null   float64
#  4   Consolidation                               35377 non-null   float64
#  5   Edema                                       96892 non-null   float64
#  6   Enlarged Cardiomediastinum                  31333 non-null   float64
#  7   Fracture                                    10413 non-null   float64
#  8   Lung Lesion                                 14547 non-null   float64
#  9   Lung Opacity                                87445 non-null   float64
#  10  No Finding                                  143352 non-null  float64
#  11  Pleural Effusion                            128890 non-null  float64
#  12  Pleural Other                               5106 non-null    float64
#  13  Pneumonia                                   98730 non-null   float64
#  14  Pneumothorax                                73538 non-null   float64
#  15  Support Devices                             89593 non-null   float64
#  16  dicom_id                                    377095 non-null  object
#  17  PerformedProcedureStepDescription           341588 non-null  object
#  18  ViewPosition                                361326 non-null  object
#  19  Rows                                        377095 non-null  int64
#  20  Columns                                     377095 non-null  int64
#  21  StudyDate                                   377095 non-null  int64
#  22  StudyTime                                   377095 non-null  float64
#  23  ProcedureCodeSequence_CodeMeaning           377095 non-null  object
#  24  ViewCodeSequence_CodeMeaning                360598 non-null  object
#  25  PatientOrientationCodeSequence_CodeMeaning  335930 non-null  object
# dtypes: float64(15), int64(5), object(6)
# memory usage: 77.7+ MB

# %% [markdown]
# #### Core_ICU_CXR Fusion

# %%
df_core_icu_cxr_fusion = df_core_icu_fusion.merge(df_cxr_merged, on=("subject_id"))

# %%
df_core_icu_cxr_fusion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3227874 entries, 0 to 3227873
# Data columns (total 56 columns):
#  #   Column                                      Dtype
# ---  ------                                      -----
#  0   subject_id                                  int64
#  1   hadm_id                                     int64
#  2   admittime                                   object
#  3   dischtime                                   object
#  4   deathtime                                   object
#  5   admission_type                              object
#  6   admission_location                          object
#  7   discharge_location                          object
#  8   insurance                                   object
#  9   language                                    object
#  10  marital_status                              object
#  11  ethnicity                                   object
#  12  edregtime                                   object
#  13  edouttime                                   object
#  14  hospital_expire_flag                        int64
#  15  gender                                      object
#  16  anchor_age                                  int64
#  17  anchor_year                                 int64
#  18  anchor_year_group                           object
#  19  dod                                         object
#  20  transfer_id                                 int64
#  21  eventtype                                   object
#  22  careunit                                    object
#  23  intime_x                                    object
#  24  outtime_x                                   object
#  25  stay_id                                     int64
#  26  first_careunit                              object
#  27  last_careunit                               object
#  28  intime_y                                    object
#  29  outtime_y                                   object
#  30  los                                         float64
#  31  study_id                                    int64
#  32  Atelectasis                                 float64
#  33  Cardiomegaly                                float64
#  34  Consolidation                               float64
#  35  Edema                                       float64
#  36  Enlarged Cardiomediastinum                  float64
#  37  Fracture                                    float64
#  38  Lung Lesion                                 float64
#  39  Lung Opacity                                float64
#  40  No Finding                                  float64
#  41  Pleural Effusion                            float64
#  42  Pleural Other                               float64
#  43  Pneumonia                                   float64
#  44  Pneumothorax                                float64
#  45  Support Devices                             float64
#  46  dicom_id                                    object
#  47  PerformedProcedureStepDescription           object
#  48  ViewPosition                                object
#  49  Rows                                        int64
#  50  Columns                                     int64
#  51  StudyDate                                   int64
#  52  StudyTime                                   float64
#  53  ProcedureCodeSequence_CodeMeaning           object
#  54  ViewCodeSequence_CodeMeaning                object
#  55  PatientOrientationCodeSequence_CodeMeaning  object
# dtypes: float64(16), int64(11), object(29)
# memory usage: 1.4+ GB

# %% [markdown]
# Demographics categorical features creation

# %%
demo_embeddings = ['anchor_age', 'gender', 'ethnicity', 'marital_status', 'language', 'insurance']

for i in range (len(demo_embeddings)):
      
    df_core_icu_cxr_fusion['de_'+str(i)] = df_core_icu_cxr_fusion[demo_embeddings[i]]

# %% [markdown]
# Demographics categorical features encoding

# %%
for i in range(5):
          df_core_icu_cxr_fusion['de_'+str(i+1)] = le.fit_transform(df_core_icu_cxr_fusion['de_'+str(i+1)])

# %%
df_core_icu_cxr_fusion["de_5"].unique()
# Out:
# array([2, 1, 0])

# %%
df_core_icu_cxr_fusion = df_core_icu_cxr_fusion.drop(['anchor_age', 'gender', 'ethnicity', 'marital_status', 'language', 'insurance'], axis=1)

# %%
df_core_icu_cxr_fusion['death_status'] = np.where(df_core_icu_cxr_fusion['discharge_location'] == 'DIED' ,1,0)

# %%
df_core_icu_cxr_fusion = df_core_icu_cxr_fusion.drop(['discharge_location'], axis =1)

# %%
df_core_icu_cxr_fusion.columns
# Out:
# Index(['subject_id', 'hadm_id', 'admittime', 'dischtime', 'deathtime',
#        'admission_type', 'admission_location', 'edregtime', 'edouttime',
#        'hospital_expire_flag', 'anchor_year', 'anchor_year_group', 'dod',
#        'transfer_id', 'eventtype', 'careunit', 'intime_x', 'outtime_x',
#        'stay_id', 'first_careunit', 'last_careunit', 'intime_y', 'outtime_y',
#        'los', 'study_id', 'Atelectasis', 'Cardiomegaly', 'Consolidation',
#        'Edema', 'Enlarged Cardiomediastinum', 'Fracture', 'Lung Lesion',
#        'Lung Opacity', 'No Finding', 'Pleural Effusion', 'Pleural Other',
#        'Pneumonia', 'Pneumothorax', 'Support Devices', 'dicom_id',
#        'PerformedProcedureStepDescription', 'ViewPosition', 'Rows', 'Columns',
#        'StudyDate', 'StudyTime', 'ProcedureCodeSequence_CodeMeaning',
#        'ViewCodeSequence_CodeMeaning',
#        'PatientOrientationCodeSequence_CodeMeaning', 'de_0', 'de_1', 'de_2',
#        'de_3', 'de_4', 'de_5', 'death_status'],
#       dtype='object')

# %%
df_core_icu_cxr_fusion = df_core_icu_cxr_fusion.loc[: , ['subject_id', 'hadm_id','stay_id',  'admittime','de_0', 'de_1', 'de_2',
       'de_3', 'de_4', 'de_5', 'death_status', 'study_id', 'Atelectasis', 'Cardiomegaly', 'Consolidation',
       'Edema', 'Enlarged Cardiomediastinum', 'Fracture', 'Lung Lesion',
       'Lung Opacity', 'No Finding', 'Pleural Effusion', 'Pleural Other',
       'Pneumonia', 'Pneumothorax', 'Support Devices', 'dicom_id',
       'PerformedProcedureStepDescription', 'ViewPosition', 'Rows', 'Columns',
       'StudyDate', 'StudyTime', 'ProcedureCodeSequence_CodeMeaning',
       'ViewCodeSequence_CodeMeaning',
       'PatientOrientationCodeSequence_CodeMeaning', ]]

# %%
df_core_icu_cxr_fusion.columns
# Out:
# Index(['subject_id', 'hadm_id', 'stay_id', 'admittime', 'de_0', 'de_1', 'de_2',
#        'de_3', 'de_4', 'de_5', 'death_status', 'study_id', 'Atelectasis',
#        'Cardiomegaly', 'Consolidation', 'Edema', 'Enlarged Cardiomediastinum',
#        'Fracture', 'Lung Lesion', 'Lung Opacity', 'No Finding',
#        'Pleural Effusion', 'Pleural Other', 'Pneumonia', 'Pneumothorax',
#        'Support Devices', 'dicom_id', 'PerformedProcedureStepDescription',
#        'ViewPosition', 'Rows', 'Columns', 'StudyDate', 'StudyTime',
#        'ProcedureCodeSequence_CodeMeaning', 'ViewCodeSequence_CodeMeaning',
#        'PatientOrientationCodeSequence_CodeMeaning'],
#       dtype='object')

# %%
len(df_core_icu_cxr_fusion['subject_id'].unique())
# Out:
# 20245

# %%
df_core_icu_cxr_fusion
# Out:
#          subject_id   hadm_id   stay_id            admittime  de_0  de_1  \
# 0          16296962  29416427  31295236  2163-01-12 17:53:00    29     1
# 1          16296962  29416427  31295236  2163-01-12 17:53:00    29     1
# 2          16296962  29416427  31295236  2163-01-12 17:53:00    29     1
# 3          16296962  29416427  31295236  2163-01-12 17:53:00    29     1
# 4          16296962  29035203  31832800  2163-06-13 07:15:00    29     1
# ...             ...       ...       ...                  ...   ...   ...
# 3227869    18227829  20330892  39672431  2177-11-18 11:46:00    91     1
# 3227870    18227829  20330892  39672431  2177-11-18 11:46:00    91     1
# 3227871    18227829  20330892  39672431  2177-11-18 11:46:00    91     1
# 3227872    18227829  20330892  39672431  2177-11-18 11:46:00    91     1
# 3227873    18227829  20330892  39672431  2177-11-18 11:46:00    91     1
#
#          de_2  de_3  de_4  de_5  ...  \
# 0           5     4     0     2  ...
# 1           5     4     0     2  ...
# 2           5     4     0     2  ...
# 3           5     4     0     2  ...
# 4           5     4     1     2  ...
# ...       ...   ...   ...   ...  ...
# 3227869     7     1     1     2  ...
# 3227870     7     1     1     2  ...
# 3227871     7     1     1     2  ...
# 3227872     7     1     1     2  ...
# 3227873     7     1     1     2  ...
#
#                                              dicom_id  \
# 0        b3a2415a-df19a752-86089f92-63020694-4aa485e9
# 1        b3a2415a-df19a752-86089f92-63020694-4aa485e9
# 2        b3a2415a-df19a752-86089f92-63020694-4aa485e9
# 3        b3a2415a-df19a752-86089f92-63020694-4aa485e9
# 4        b3a2415a-df19a752-86089f92-63020694-4aa485e9
# ...                                               ...
# 3227869  eadebc12-079e0e8d-17b034c1-9333cb57-a7d8bd62
# 3227870  20376daa-31970cf3-938a9fd6-82cb5f44-80c1c211
# 3227871  226d77aa-c6da08cd-f7ede193-5e1b4e81-7226691e
# 3227872  f9a82111-ef932e19-948ff9f2-a147a2e1-c8674d21
# 3227873  f520b0b9-107ac9be-5435df22-2099f93e-d0b76cad
#
#          PerformedProcedureStepDescription  ViewPosition  Rows  Columns  \
# 0                      CHEST (PORTABLE AP)            AP  3056     2544
# 1                      CHEST (PORTABLE AP)            AP  3056     2544
# 2                      CHEST (PORTABLE AP)            AP  3056     2544
# 3                      CHEST (PORTABLE AP)            AP  3056     2544
# 4                      CHEST (PORTABLE AP)            AP  3056     2544
# ...                                    ...           ...   ...      ...
# 3227869                CHEST (PORTABLE AP)            AP  3050     2539
# 3227870                CHEST (PORTABLE AP)            AP  2544     3056
# 3227871                CHEST (PORTABLE AP)            AP  2544     3056
# 3227872                CHEST (PORTABLE AP)            AP  2544     3056
# 3227873                CHEST (PORTABLE AP)            AP  2539     3050
#
#          StudyDate   StudyTime  ProcedureCodeSequence_CodeMeaning  \
# 0         21630113   34411.031                CHEST (PORTABLE AP)
# 1         21630113   34411.031                CHEST (PORTABLE AP)
# 2         21630113   34411.031                CHEST (PORTABLE AP)
# 3         21630113   34411.031                CHEST (PORTABLE AP)
# 4         21630113   34411.031                CHEST (PORTABLE AP)
# ...            ...         ...                                ...
# 3227869   21771122   73509.937                CHEST (PORTABLE AP)
# 3227870   21771125  153228.078                CHEST (PORTABLE AP)
# 3227871   21771121   14131.515                CHEST (PORTABLE AP)
# 3227872   21771119   50543.375                CHEST (PORTABLE AP)
# 3227873   21771121  181155.984                CHEST (PORTABLE AP)
#
#          ViewCodeSequence_CodeMeaning  \
# 0                    antero-posterior
# 1                    antero-posterior
# 2                    antero-posterior
# 3                    antero-posterior
# 4                    antero-posterior
# ...                               ...
# 3227869              antero-posterior
# 3227870              antero-posterior
# 3227871              antero-posterior
# 3227872              antero-posterior
# 3227873              antero-posterior
#
#          PatientOrientationCodeSequence_CodeMeaning
# 0                                             Erect
# 1                                             Erect
# 2                                             Erect
# 3                                             Erect
# 4                                             Erect
# ...                                             ...
# 3227869                                       Erect
# 3227870                                       Erect
# 3227871                                       Erect
# 3227872                                       Erect
# 3227873                                         NaN
#
# [3227874 rows x 36 columns]

# %% [markdown]
# Selecting 1 patient

# %%
df_core_icu_cxr_fusion14811141 = df_core_icu_cxr_fusion.loc[df_core_icu_cxr_fusion['subject_id'] == 14811141 ]

# %%
df_core_icu_cxr_fusion14811141
# Out:
#          subject_id   hadm_id   stay_id            admittime  de_0  de_1  \
# 2790418    14811141  26884919  38772375  2189-08-17 00:46:00    82     0
# 2790419    14811141  26884919  38772375  2189-08-17 00:46:00    82     0
# 2790420    14811141  26884919  38772375  2189-08-17 00:46:00    82     0
# 2790421    14811141  26884919  38772375  2189-08-17 00:46:00    82     0
#
#          de_2  de_3  de_4  de_5  ...  \
# 2790418     7     3     1     1  ...
# 2790419     7     3     1     1  ...
# 2790420     7     3     1     1  ...
# 2790421     7     3     1     1  ...
#
#                                              dicom_id  \
# 2790418  26b72926-4afaa4c9-b24ece3a-ee2a554a-4add0f4a
# 2790419  26b72926-4afaa4c9-b24ece3a-ee2a554a-4add0f4a
# 2790420  26b72926-4afaa4c9-b24ece3a-ee2a554a-4add0f4a
# 2790421  26b72926-4afaa4c9-b24ece3a-ee2a554a-4add0f4a
#
#          PerformedProcedureStepDescription  ViewPosition  Rows  Columns  \
# 2790418                CHEST (PORTABLE AP)            AP  3043     2539
# 2790419                CHEST (PORTABLE AP)            AP  3043     2539
# 2790420                CHEST (PORTABLE AP)            AP  3043     2539
# 2790421                CHEST (PORTABLE AP)            AP  3043     2539
#
#          StudyDate   StudyTime  ProcedureCodeSequence_CodeMeaning  \
# 2790418   21890817  125809.906                CHEST (PORTABLE AP)
# 2790419   21890817  125809.906                CHEST (PORTABLE AP)
# 2790420   21890817  125809.906                CHEST (PORTABLE AP)
# 2790421   21890817  125809.906                CHEST (PORTABLE AP)
#
#          ViewCodeSequence_CodeMeaning  \
# 2790418              antero-posterior
# 2790419              antero-posterior
# 2790420              antero-posterior
# 2790421              antero-posterior
#
#          PatientOrientationCodeSequence_CodeMeaning
# 2790418                                       Erect
# 2790419                                       Erect
# 2790420                                       Erect
# 2790421                                       Erect
#
# [4 rows x 36 columns]

# %%
#Sample of 10 patients

#sample = read_csv(constants.icu_cxr_patients_sample10)

#df_core_icu_cxr_fusion_sample = df_core_icu_cxr_fusion.loc[df_core_icu_cxr_fusion['subject_id'].isin(sample)]

'''
0    14811141
1    18874374
2    11272213
3    13762583
4    18087960
5    13500443
6    12189736
7    14024750
8    19136566
9    18481208'''
# Out:
# '\n0    14811141\n1    18874374\n2    11272213\n3    13762583\n4    18087960\n5    13500443\n6    12189736\n7    14024750\n8    19136566\n9    18481208'

# %%
df_core_icu_cxr_fusion_sample
# Out:
#          subject_id   hadm_id   stay_id            admittime  de_0  de_1  \
# 1214362    18874374  26560714  31332432  2143-10-14 04:32:00    80     0
# 1214363    18874374  26560714  31332432  2143-10-14 04:32:00    80     0
# 1214364    18874374  26560714  31332432  2143-10-14 04:32:00    80     0
# 1214365    18874374  26560714  31332432  2143-10-14 04:32:00    80     0
# 1214366    18874374  26560714  31332432  2143-10-14 04:32:00    80     0
# 1214367    18874374  25548314  36493337  2143-10-05 13:19:00    80     0
# 1214368    18874374  25548314  36493337  2143-10-05 13:19:00    80     0
# 1214369    18874374  25548314  36493337  2143-10-05 13:19:00    80     0
# 1214370    18874374  25548314  36493337  2143-10-05 13:19:00    80     0
# 2790418    14811141  26884919  38772375  2189-08-17 00:46:00    82     0
# 2790419    14811141  26884919  38772375  2189-08-17 00:46:00    82     0
# 2790420    14811141  26884919  38772375  2189-08-17 00:46:00    82     0
# 2790421    14811141  26884919  38772375  2189-08-17 00:46:00    82     0
#
#          de_2  de_3  de_4  de_5  ...  \
# 1214362     1     1     0     1  ...
# 1214363     1     1     0     1  ...
# 1214364     1     1     0     1  ...
# 1214365     1     1     0     1  ...
# 1214366     1     1     0     1  ...
# 1214367     1     1     0     1  ...
# 1214368     1     1     0     1  ...
# 1214369     1     1     0     1  ...
# 1214370     1     1     0     1  ...
# 2790418     7     3     1     1  ...
# 2790419     7     3     1     1  ...
# 2790420     7     3     1     1  ...
# 2790421     7     3     1     1  ...
#
#                                              dicom_id  \
# 1214362  4d9de708-0d2bc7fe-d09123f4-cddd314f-81bceaad
# 1214363  4d9de708-0d2bc7fe-d09123f4-cddd314f-81bceaad
# 1214364  4d9de708-0d2bc7fe-d09123f4-cddd314f-81bceaad
# 1214365  4d9de708-0d2bc7fe-d09123f4-cddd314f-81bceaad
# 1214366  4d9de708-0d2bc7fe-d09123f4-cddd314f-81bceaad
# 1214367  4d9de708-0d2bc7fe-d09123f4-cddd314f-81bceaad
# 1214368  4d9de708-0d2bc7fe-d09123f4-cddd314f-81bceaad
# 1214369  4d9de708-0d2bc7fe-d09123f4-cddd314f-81bceaad
# 1214370  4d9de708-0d2bc7fe-d09123f4-cddd314f-81bceaad
# 2790418  26b72926-4afaa4c9-b24ece3a-ee2a554a-4add0f4a
# 2790419  26b72926-4afaa4c9-b24ece3a-ee2a554a-4add0f4a
# 2790420  26b72926-4afaa4c9-b24ece3a-ee2a554a-4add0f4a
# 2790421  26b72926-4afaa4c9-b24ece3a-ee2a554a-4add0f4a
#
#          PerformedProcedureStepDescription  ViewPosition  Rows  Columns  \
# 1214362                CHEST (PORTABLE AP)            AP  3056     2544
# 1214363                CHEST (PORTABLE AP)            AP  3056     2544
# 1214364                CHEST (PORTABLE AP)            AP  3056     2544
# 1214365                CHEST (PORTABLE AP)            AP  3056     2544
# 1214366                CHEST (PORTABLE AP)            AP  3056     2544
# 1214367                CHEST (PORTABLE AP)            AP  3056     2544
# 1214368                CHEST (PORTABLE AP)            AP  3056     2544
# 1214369                CHEST (PORTABLE AP)            AP  3056     2544
# 1214370                CHEST (PORTABLE AP)            AP  3056     2544
# 2790418                CHEST (PORTABLE AP)            AP  3043     2539
# 2790419                CHEST (PORTABLE AP)            AP  3043     2539
# 2790420                CHEST (PORTABLE AP)            AP  3043     2539
# 2790421                CHEST (PORTABLE AP)            AP  3043     2539
#
#          StudyDate   StudyTime  ProcedureCodeSequence_CodeMeaning  \
# 1214362   21431014   24132.578                CHEST (PORTABLE AP)
# 1214363   21431014   24132.578                CHEST (PORTABLE AP)
# 1214364   21431014   24132.578                CHEST (PORTABLE AP)
# 1214365   21431014   24132.578                CHEST (PORTABLE AP)
# 1214366   21431014   24132.578                CHEST (PORTABLE AP)
# 1214367   21431014   24132.578                CHEST (PORTABLE AP)
# 1214368   21431014   24132.578                CHEST (PORTABLE AP)
# 1214369   21431014   24132.578                CHEST (PORTABLE AP)
# 1214370   21431014   24132.578                CHEST (PORTABLE AP)
# 2790418   21890817  125809.906                CHEST (PORTABLE AP)
# 2790419   21890817  125809.906                CHEST (PORTABLE AP)
# 2790420   21890817  125809.906                CHEST (PORTABLE AP)
# 2790421   21890817  125809.906                CHEST (PORTABLE AP)
#
#          ViewCodeSequence_CodeMeaning  \
# 1214362              antero-posterior
# 1214363              antero-posterior
# 1214364              antero-posterior
# 1214365              antero-posterior
# 1214366              antero-posterior
# 1214367              antero-posterior
# 1214368              antero-posterior
# 1214369              antero-posterior
# 1214370              antero-posterior
# 2790418              antero-posterior
# 2790419              antero-posterior
# 2790420              antero-posterior
# 2790421              antero-posterior
#
#          PatientOrientationCodeSequence_CodeMeaning
# 1214362                                       Erect
# 1214363                                       Erect
# 1214364                                       Erect
# 1214365                                       Erect
# 1214366                                       Erect
# 1214367                                       Erect
# 1214368                                       Erect
# 1214369                                       Erect
# 1214370                                       Erect
# 2790418                                       Erect
# 2790419                                       Erect
# 2790420                                       Erect
# 2790421                                       Erect
#
# [13 rows x 36 columns]
